# %% [markdown]
# # 7 years on, revisiting the demands of the Tunisian and Egyptian springs
#
# [S. Moraes Sarmento](mailto:simao.moraessarmento@epfl.ch), [K. Mrini](mailto:khalil.mrini@epfl.ch), [K. Omari](mailto:khalid.omari@epfl.ch)
#
# ## Table of Contents
#
# ### [1. Selecting Keyphrases to Filter Text Data](#1)
#
# - [1.1. Tokenization and Filtering based on Parts of Speech](#11)
#
# - [1.2. Forming N-Grams](#12)
#
# - [1.3. Downloading Wikipedia Articles](#13)
#
# - [1.4. Extracting Most Popular Tokens](#14)
#
# - [1.5. Extracting Keyphrases from Wikipedia Articles](#15)
#
# - [1.6. Examples of Keyphrases](#16)
#
# - [1.7. Comparing Texts to Keyphrases](#17)
#
# ### [2. Sampling and Filtering the 2.1 TB of Compressed Data](#2)
# - [2.1. Reading a Single .protostream File](#21)
#
# - [2.2. Reading the Compressed .tar.gz Files to Pandas DataFrame](#22)
#
# - [2.3. Loading the DataFrame](#23)
#
# - [2.4. Data Cleaning](#24)
#
# - [2.5. Data Analysis: Language and Post Type Distributions](#25)
#
# - [2.6. How different are Jan. 14 and Feb. 11 in Data Distributions?](#26)
#     - [2.6.1. Language and Post Type Distributions](#261)
#     - [2.6.2. Country Distributions](#262)
#
# - [2.7. Keyword Detection by Language and Post Type](#27)
#     - [2.7.1. Keyword Extraction](#271)
#     - [2.7.2. Keywords on January 14](#272)
#     - [2.7.3. Keywords on February 11](#273)
#
# ### [3. Gauging the Accuracy of the Keyphrases](#3)
# - [3.1. Scraping Deutsche Welle Articles on the Tunisian and Egyptian Revolutions](#31)
#
# - [3.2. Article Classification Approach](#32)
#
# - [3.3. Classifying the DW Articles by Country](#33)
#
# ### [4. Extracting and Filtering the 2.1 TB of `Spinn3r` data](#4)
# - [4.1. Using the Cluster](#41)
#
# - [4.2. Handling the Distributed Pickle File Locally](#42)
#
# - [4.3. Loading and Cleaning the `DataFrames`](#43)
#
# - [4.4. Splitting by Country](#44)
#     - [4.4.1. Egypt Statistics](#441)
#     - [4.4.2. Tunisia Statistics](#442)
#
# - [4.5. Distribution of Posts over Days](#45)
#     - [4.5.1. Egypt Time Series](#451)
#     - [4.5.2. Tunisia Time Series](#452)
#
# ### [5. Topic Detection](#5)
# - [5.1. Preprocessing All Posts](#51)
#     - [5.1.1. Tokenizing and Removing Stop Words](#511)
#     - [5.1.2. Adding Bigrams](#512)
#     - [5.1.3. Simplifying Country Selection](#513)
#
# - [5.2. Topic Detection Methods](#52)
#     - [5.2.1. Bag-of-Words Representation](#521)
#     - [5.2.2. LSA Model](#522)
#     - [5.2.3. LDA Model](#523)
#
# - [5.3. Showcase of Topic Modelling Results](#53)
#     - [5.3.1. Egypt, Arabic, Forum](#531)
#     - [5.3.2. Egypt, English, Social Media](#532)
#     - [5.3.3. Tunisia, English, News](#533)
#     - [5.3.4. Tunisia, French, Web Blogs](#534)

# %% [markdown]
# # 1. Selecting Keyphrases to Filter Text Data<a class="anchor" id="1"></a>
#
# **Problem**
#
# Having seen the data, we noticed that large parts of it were not related to the Arab Spring revolutions of 2011. Spinn3r, the company providing the data, is actually promoting their scraping API by doing so.
#
# Therefore, we must find keyphrases to filter this data based on the Tunisian and Egyptian revolutions.
#
# **Solution Proposed**
#
# Using **Wikipedia** articles for the Tunisian and Egyptian revolutions, we ***automatically*** extract the keyphrase that will be used for filtering. Given that the data is provided in various languages, we choose to focus on three relevant languages: **English**, **French**, and **Arabic**.
#
# **Added Value**
#
# In comparison with the only paper participating in the 2011 ICWSM Spinn3r Challenge, <a href='http://www.icwsm.org/2011/documents/IDC2011.pdf'>*Revolution 2.0 in Tunisia and Egypt: Reactions and Sentiments in the Online World*</a>:
# 1. We use **keyphrases** instead of **keywords**, by using n-grams;
# 2. We do not choose keyphrases manually, but extract them from Wikipedia automatically;
# 3. We provide insight by evaluating data not only in English, but in two additional languages: French, Tunisia's colonial-era and second most popular language, and Arabic, the native language of both the peoples of Tunisia and Egypt.
#
# **In the following:** we first establish helper functions before compiling it in one function to get the keyphrases for each language, and each country.
#
# ## 1.1. Tokenization and Filtering based on Parts of Speech<a class="anchor" id="11"></a>
#
# The following are the languages that we focus on throughout the project:

# %%
EN = 'english'
FR = 'french'
AR = 'arabic'
LANGS = [EN, FR, AR]

# %% [markdown]
# We use a *Regular Expression Tokenizer* with the *NLTK* (Natural Language Toolkit) package for the textual data.
#
# We want our keyphrases to contain **interesting words**, and therefore we eliminate stop words using the corresponding corpus from NLTK, and we eliminate verbs and adverbs using the **state-of-the-art Stanford POS Tagger**. We have to check the distinct *tag sets* of each language's POS tagger for filtering.

# %%
# NLTK Imports
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.tag import StanfordPOSTagger

# Setting up POS Tagger and Stop Word Lists
TOKENIZER = RegexpTokenizer(r'\w+')
STOPWORDS = dict((language, set(stopwords.words(language))) for language in LANGS)

# Setting up POS Taggers
STANFORD_PREFIX = './Stanford POS Taggers/'
JAR = 'stanford-postagger.jar'
POS_TAGGERS = dict((language, 
                    StanfordPOSTagger(STANFORD_PREFIX + language + '.tagger', 
                                      STANFORD_PREFIX + JAR)) 
                   for language in LANGS)

# Tags of Adverbs and Verbs in each language's POS Tagger
REFUSED_POS_TAGS = {EN: ['V', 'R', 'MD', 'IN', 'CD'], 
                    FR: ['ADV', 'D', 'PREF', 'V'],
                    AR: ['V']}

def tag_is_allowed(tag, language):
    """
    Determines if given tag is not a verb or adverb using REFUSED_POS_TAGS.
    :param tag: string, tag of a word as determined by POS Tagger
    :param language: string
    :return: Boolean, True if tag should be kept
    """
    for other_tag in REFUSED_POS_TAGS[language]:
        if tag.startswith(other_tag):
            return False
    return True

def tokenize_without_stopwords(text, language):
    """
    Removes stop words and digit-only tokens.
    :param text: string
    :param language: string
    :return: list of strings
    """
    tokens = [token for token in TOKENIZER.tokenize(text.lower()) 
              if token not in STOPWORDS[language] 
              and not token.isdigit()]
    return tokens

def preprocess_for_keyphrases(text, language):
    """
    Tokenizes, removes stopwords and digit-only tokens, removes verbs and adverbs.
    :param text: string
    :param language: string, language of text
    :return: list of strings, tokens of text
    """
    # Removing stop words, digit-only tokens
    tokens = tokenize_without_stopwords(text, language)
    # POS-Tagging
    tokens_with_tags = POS_TAGGERS[language].tag(tokens)
    # Handling the case of the Arabic POS Tagger, as it concatenates token and POS tag
    if language == AR:
        tokens_with_tags = [tag[1].split('/') for tag in tokens_with_tags]
    # POS-Tag filtering
    tokens = [token for token, tag in tokens_with_tags 
              if tag_is_allowed(tag, language)]
    return tokens
# Out:
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/nltk/tag/stanford.py:149: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordPOSTagger, self).__init__(*args, **kwargs)
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/nltk/tag/stanford.py:149: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordPOSTagger, self).__init__(*args, **kwargs)
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/nltk/tag/stanford.py:149: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordPOSTagger, self).__init__(*args, **kwargs)

# %% [markdown]
# ## 1.2. Forming N-Grams<a class="anchor" id="12"></a>
#
# Having formed tokens, we want now to give sense to keyphrases by forming n-grams. We use NLTK for that as well. We use the regular expression package to have the newly-formed n-grams as one token.

# %%
# NLTK and regexp Imports
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder
import re

def form_n_grams(tokens, threshold):
    """
    Forms tokens that are n-grams with a minimum frequency threshold.
    :param tokens: list of strings
    :param threshold: int
    :return: list of strings, n-gram'd tokens
    """
    # Bigram Finder
    finder = BigramCollocationFinder.from_words(tokens)
    finder.apply_freq_filter(threshold)
    # Bigrams
    scored_bigrams = finder.score_ngrams(BigramAssocMeasures.raw_freq)
    # Joining Bigrams in the text
    text = ' '.join(tokens)
    for (word1, word2), score in scored_bigrams:
        text = re.sub(r'\b{}\b \b{}\b'.format(word1, word2), '{}_{}'.format(word1, word2), text)
    tokens = text.split(' ')
    return tokens

# %% [markdown]
# We form n-grams over different rounds, each round incrementing the *n* parameter.
#
# Given that Arabic is more agglutinative than English and French, it gets less rounds. The following are the rounds that we define to form n-grams:

# %%
NGRAM_RANGE = {EN: range(3), 
               FR: range(3), 
               AR: range(1,3)}

# %% [markdown]
# The following function forms the n-grams over rounds. To keep interesting tokens, we remove tokens that have less than 4 characters. We remove these tokens only after forming n-grams because we noticed that short unigrams can form interesting n-grams.

# %%
MIN_CHAR_COUNT = 4

def n_gram_rounds(tokens, language, threshold):
    """
    Forms n-grams over rounds given unigram tokens.
    :param tokens: list of strings
    :param language: string
    :param threshold: int
    :return: list of strings, n-gram tokens
    """
    for ngram_round in NGRAM_RANGE[language]:
        tokens = form_n_grams(tokens, threshold + ngram_round)
    tokens = [token for token in tokens if len(token) >= MIN_CHAR_COUNT]
    return tokens

# %% [markdown]
# ## 1.3. Downloading Wikipedia Articles<a class="anchor" id="13"></a>
#
# Throughout the project, we focus on the two following countries:

# %%
EG = 'Egypt'
TN = 'Tunisia'

# %% [markdown]
# We use the following articles to extract keyphrases.

# %%
WIKI_ARTICLES = {TN: {EN: 'Tunisian Revolution', 
                      FR: 'Révolution tunisienne', 
                      AR: 'الثورة التونسية'},
                 EG: {EN: 'Egyptian Revolution of 2011', 
                      FR: 'Révolution égyptienne de 2011', 
                      AR: 'ثورة 25 يناير'}}

# %% [markdown]
# We use the *Wikipedia* Python package to extract article content.

# %%
# Wikipedia import
import wikipedia

def download_wikipedia_article(wiki_article, language):
    """
    Downloads the text content of a given Wikipedia article in a given language.
    :param wiki_article: string, title of article
    :param language: string
    :return: string
    """
    wikipedia.set_lang(language[:2])
    wiki = wikipedia.page(wiki_article)
    return wiki.content

# %% [markdown]
# ## 1.4. Extracting Most Popular Tokens<a class="anchor" id="14"></a>
#
# Once we have formed phrases and have them as a list of strings, we use `Counter` to get the most popular phrases.

# %%
from collections import Counter

def get_most_popular_tokens(tokens, num_keyphrases):
    """
    Gets most popular num_keywords elements of tokens.
    :param tokens: list of strings
    :param num_keyphrases: int
    :return: list of strings
    """
    counter = Counter(tokens)
    keyphrases = [word.replace('_', ' ') for word, score in counter.most_common(num_keyphrases)]
    return keyphrases

# %% [markdown]
# ## 1.5. Extracting Keyphrases from Wikipedia Articles<a class="anchor" id="15"></a>
#
# We concatenate all of the above in the following function:

# %%
def get_wikipedia_keyphrases(wiki_article, language, num_keyphrases=50, threshold=1):
    """
    Gets Keyphrases from Wikipedia Article.
    :param wiki_article: string, name of Wikipedia Article
    :param language: string
    :param num_keyphrases: int, number of keyphrases to extract
    :param threshold: int, n-gram formation threshold
    :return: list of strings, keyphrases
    """
    wiki_content = download_wikipedia_article(wiki_article, language)
    unigram_tokens = preprocess_for_keyphrases(wiki_content, language)
    ngram_tokens = n_gram_rounds(unigram_tokens, language, threshold)
    keyphrases = get_most_popular_tokens(ngram_tokens, num_keyphrases)
    return keyphrases

# %% [markdown]
# We extract 50 keyphrases, per country, and per language:

# %%
keyphrase_dict = dict((country, 
                       dict((language, get_wikipedia_keyphrases(WIKI_ARTICLES[country][language], language)) 
                            for language in WIKI_ARTICLES[country])) 
                      for country in WIKI_ARTICLES)

# %% [markdown]
# We save these keywords in the `Keyphrases` folder:

# %%
for country in keyphrase_dict:
    for language in keyphrase_dict[country]:
        keyphrase_file = open('./Keyphrases/{}_{}.txt'.format(country, language), 'w')
        print('\n'.join(keyphrase_dict[country][language]), file=keyphrase_file)
        keyphrase_file.close()

# %% [markdown]
# ## 1.6. Examples of Keyphrases<a class="anchor" id="16"></a>

# %% [markdown]
# In the following, we provide an example of keyphrases for English in **Tunisia**. The most popular is `ben ali`, the last name of Tunisia's ousted president. The phrase `sidi bouzid` designates the city where protests started in January 2011.

# %%
keyphrase_dict[TN][EN][:10]
# Out:
# ['ben ali',
#  'tunisia',
#  'arab world',
#  'protests',
#  'sidi bouzid',
#  'prime minister',
#  'tunisian',
#  'security forces',
#  'foreign minister',
#  'january']

# %% [markdown]
# Hereafter is an sample of keyphrases for English in **Egypt**. The most popular one is `tahrir square`, a public square in the Egyptian capital, Cairo, where the protesters camped throughout the protests. The `muslim brotherhood` is the opposition party that later came into power. Here, the Egyptian ousted president's full name, `hosni mubarak`, comes up as one of the keyphrases.

# %%
keyphrase_dict[EG][EN][:10]
# Out:
# ['tahrir square',
#  'muslim brotherhood',
#  'social media',
#  'revolution',
#  'hosni mubarak',
#  'egyptian revolution',
#  'protests',
#  'protesters',
#  'prime minister',
#  'human rights']

# %% [markdown]
# ## 1.7. Comparing Texts to Keyphrases<a class="anchor" id="17"></a>

# %% [markdown]
# Given these keyphrases, we want to estimate how many of those appear in a given text:

# %%
def keyphrase_score(country, language, text):
    """
    Computes how many keyphrases for the country and language are in the text.
    :param country: string
    :param language: string
    :param text: string
    :return: int
    """
    score = 0
    for keyphrase in keyphrase_dict[country][language]:
        if keyphrase in text:
            score += 1
    return score

# %% [markdown]
# We use this function to compute the keyphrase scores per country and for a given language and a given text:

# %%
def compute_keyphrase_scores(text, language):
    """
    Computes keyphrase scores for all countries given text and language.
    Returns False if all scores are inferior to 4.
    :param text: string
    :param language: string
    :return: dict or boolean
    """
    new_text = text.lower()
    data = {}
    score_sum = 0
    for country in keyphrase_dict:
        score = keyphrase_score(country, language, new_text)
        data[country] = score
        score_sum += score
    if score_sum <= 4:
        return False
    else:
        return data

# %% [markdown]
# # 2. Sampling and Filtering the 2.1 TB of Compressed Data<a class="anchor" id="2"></a>
#
# **Steps to Reach Text Data**
#
# The files are compressed in `.tar.gz` format. The steps to reach text data are more complex than we thought:
# 1. We downloaded a sample, and the decompressed files are in `.protostream` format. This format **lacks documentation**. A `.protostream` file is a stream of Google's `protobuf` format.
# 2. The `.protostream` format requires `.proto` files to extract them. We found these files on the internet, not on Spinn3r's website. This format was originally made for Java, and has difficult compatibility with Python.
# 3. We installed the C++ `protoc` library to make `.py` files out of `.proto` files. These `.py` files contain Python classes that we can use to read the data. The `.proto` and `.py` files can be found on our GitHub repo.
# 4. We found the code to read the text data on a *Stackoverflow* answer rated `-1`, rather than on Spinn3r's website or the `protobuf` documentation.
#
# **Sample Evaluated**
#
# We downloaded compressed samples of about **40 GB** for the days of **January 14, 2011** and **February 11, 2011**, respectively the days of the resignation of the presidents of Tunisia and Egypt.
#
# **In the following:** we first read the data and filter it based on the keywords found in the first section.
#
# ## 2.1. Reading a Single `.protostream` File <a class="anchor" id="21"></a>
#
# We first import the `.py` files that we got out of the `.proto` files. The `spinn3rApi_pb2.py` file contains the classes needed to parse the bytes of a given internet entry. The `protoStream_pb2.py` file contains the classes needed to separate entries inside a `.protostream` file, most notably the `ProtoStreamDelimiter` class.

# %%
import proto.spinn3rApi_pb2 as proto_api
import proto.protoStream_pb2 as proto_stream

DELIMITER = proto_stream.ProtoStreamDelimiter()

# %% [markdown]
# We will need the following decoder to separate entries in a `.protostream` file.

# %%
from google.protobuf.internal.decoder import _DecodeVarint32

# length, pos = decoder(file, pos) => pos is starting point, length is the length of the record in file
DECODER = _DecodeVarint32

# %% [markdown]
# In the files we find, we find the languages as two-letter language codes. We will need a mapping to full-length name:

# %%
CODE_TO_LANG = dict((language[:2], language) for language in LANGS)

# %% [markdown]
# We use the following functions to read a single `.protostream` file onto a list of `dict` instances. We use `BeautifulSoup` for some `html` data, that is itself `zlib`-encoded.

# %%
import zlib
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

def try_to_get_content(entry):
    """
    Attempts to get content from an entry.
    :param entry: contentApi.Entry
    :return: string
    """
    try:
        return BeautifulSoup(zlib.decompress(entry.feed_entry.content.data), "html.parser").text
    except:
        return ""

def read_protostream_file(file):
    """
    Reads a single .protostream file.
    :param file: bytes
    :return: list of dictionaries
    """
    data_rows = []
    
    length, pos = DECODER(file, 0)
    pos += length

    while pos < len(file):
        length, pos = DECODER(file, pos)
        DELIMITER.ParseFromString(file[pos:pos + length])
        if DELIMITER.delimiter_type == DELIMITER.END:
            break
            
        # This means we found an Entry
        elif DELIMITER.delimiter_type == DELIMITER.ENTRY:
            pos += length
            length, pos = DECODER(file, pos)
            
            # The Entry Class enables to read the contents of the record
            entry = proto_api.Entry()
            entry.ParseFromString(file[pos:pos + length])
            
            lang_code = entry.feed_entry.lang[0].code
            
            # Proceeding if the language is English, French or Arabic
            if lang_code in CODE_TO_LANG:
                post_title = entry.feed_entry.title
                post_content = try_to_get_content(entry)
                data = compute_keyphrase_scores(post_title + ' ' + post_content, 
                                                CODE_TO_LANG[lang_code])
                if data:
                    # Language Code
                    data['Lang_Code'] = lang_code
                    
                    # Post Title
                    data['Post_Title'] = post_title
                    
                    # Post Content
                    if post_content:
                        data['Post_Content'] = post_content
                    
                    # Language Probability
                    try:
                        data['Lang_Prob'] = entry.feed_entry.lang[0].probability
                    except:
                        pass

                    # Link
                    try:
                        data['Post_Link'] = entry.feed_entry.link[0].href
                    except:
                        pass

                    # Author Name
                    try:
                        data['Author_Name'] = entry.feed_entry.author[0].name
                    except:
                        pass

                    # Author Link
                    try:
                        data['Author_Link'] = entry.feed_entry.author[0].link[0].href
                    except:
                        pass

                    # Date & Time
                    try:
                        data['Datetime'] = entry.feed_entry.last_published
                    except:
                        pass

                    # Identifier
                    try:
                        data['Identifier'] = entry.feed_entry.identifier
                    except:
                        pass

                    # Spam Probability
                    try:
                        data['Spam'] = entry.feed_entry.spam_probability
                    except:
                        pass

                    # Publisher Type
                    try:
                        data['Type'] = entry.source.publisher_type
                    except:
                        pass

                    # Category
                    try:
                        data['Category'] = entry.feed_entry.category
                    except:
                        pass

                    data_rows.append(data)
        pos += length
    return data_rows

# %% [markdown]
# ## 2.2. Reading the Compressed `.tar.gz` Files to Pandas `DataFrame`<a class="anchor" id="22"></a>
#
# We downloaded the files in an external harddrive. We set up the following variables:

# %%
TAR_PREFIX = '/Volumes/Khalil Mrini/'
JSON_PREFIX = './Text Data/'
FILES = '01-14-OTHER 01-14-SOCIAL_MEDIA 02-11-OTHER 02-11-SOCIAL_MEDIA'.split(' ')
TAR = '.tar.gz'
JSON = '.json'

# %% [markdown]
# To read a `.tar.gz` file without decompressing it, we use the following package:

# %%
import tarfile

# %% [markdown]
# We save the files to Pandas `DataFrame`.

# %%
import pandas as pd

# %% [markdown]
# In the following we read the `.tar.gz` files and save them to `.json` files as Pandas `DataFrame`:

# %%
for file_name in FILES:
    data_rows = []
    
    # Reading the .tar.gz file
    tar = tarfile.open(TAR_PREFIX + file_name + TAR, "r:gz")
    
    # Members are the components (files, folders...) found inside the compressed file
    members = tar.getmembers()
    member_count = len(members)
    
    # Reading each individual file
    for member_index in range(member_count):
        file_data = tar.extractfile(members[member_index])
        if file_data is not None:
            content = file_data.read()
            data_rows.extend(read_protostream_file(content))
    
    # Compiling as Pandas DataFrame, then saving to json files
    df = pd.DataFrame(data_rows)
    df.to_json('{}{}.json'.format(JSON_PREFIX, file_name))

# %% [markdown]
# ## 2.3. Loading the `DataFrame`<a class="anchor" id="23"></a>
#
# In the following we will need `numpy`:

# %%
import numpy as np

# %% [markdown]
# We define the following functions to load the files from each date into the corresponding `DataFrame`:

# %%
def load_df():
    """
    Loads the files into dataframes per date
    :return: DataFrame
    """
    df = pd.DataFrame()
    for file in FILES:
        file_df = pd.read_json(JSON_PREFIX + file + '.json')
        file_df['Month'] = file_df.Datetime.apply(lambda row: get_month(row, int(file[:2])))
        df = df.append(file_df, ignore_index=True)
    return df

def get_month(row, default_month):
    """
    Returns the corresponding month or default_month if Nan
    :param row:  
    """
    if not np.isnan(row.month):
        return row.month
    else:
        return default_month

# %% [markdown]
# We can get a quick glance at the `DataFrame` with the most relevant posts:

# %%
df = load_df()
df.sort_values([EG, TN], ascending=False).head()
# Out:
#       Author_Link    Author_Name Category            Datetime  Egypt  \
# 22669              Lara Friedman       {} 2011-02-11 20:47:03     26
# 34615                    الشاعلر       {} 2011-02-11 19:54:35     25
# 35871                    الشاعلر       {} 2011-02-11 19:54:35     25
# 43560                                  {} 2011-02-11 21:01:00     25
# 41135                      ahaha       {} 2011-02-11 19:05:24     24
#
#                 Identifier Lang_Code  Lang_Prob  \
# 22669  1297460101090980356        en         -1
# 34615  1297459865090980374        ar         -1
# 35871  1297456634081625128        ar         -1
# 43560  1297461312090849299        en         -1
# 41135  1297451451119193629        ar         -1
#
#                                             Post_Content  \
# 22669  \n======================= APN Legislative Roun...
# 34615  \nجلة التايم الأمريكية تضع الرئيس صالح في المر...
# 35871  \nجلة التايم الأمريكية تضع الرئيس صالح في المر...
# 43560  Key events during Egypt's uprising:- Jan. 25 -...
# 41135  مساعد وزير الداخلية :ثروة العادلي 17 مليار و 2...
#
#                                                Post_Link  \
# 22669  http://peacenow.org/entries/legislative_round-...
# 34615  http://forum.sh3bwah.maktoob.com/showthread.ph...
# 35871  http://forum.sh3bwah.maktoob.com/showthread.ph...
# 43560  http://www.star-telegram.com/2011/02/11/284216...
# 41135  http://www.egyptsons.com/misr/showthread.php?t...
#
#                                               Post_Title  Spam  Tunisia  \
# 22669          Legislative Round-Up: Week Ending 2/11/11     0       15
# 34615  ثورتي تونس ومصر بثت الخوف في قلب صالح فسارع إل...     0       33
# 35871  ثورتي تونس ومصر بثت الخوف في قلب صالح فسارع إل...     0       33
# 43560            A look at how Egypt's uprising unfolded     0       18
# 41135  مساعد وزير الداخلية :ثروة العادلي 17 مليار و 2...     0       13
#
#                   Type  Month
# 22669  MAINSTREAM_NEWS      2
# 34615            FORUM      2
# 35871            FORUM      2
# 43560  MAINSTREAM_NEWS      2
# 41135            FORUM      2

# %% [markdown]
# ## 2.4. Data Cleaning<a class="anchor" id="24"></a>
#
# In this section, we aim to **clean** our df by **deleting meaningless information**. We start by checking the columns of the df:

# %%
df.columns
# Out:
# Index(['Author_Link', 'Author_Name', 'Category', 'Datetime', 'Egypt',
#        'Identifier', 'Lang_Code', 'Lang_Prob', 'Post_Content', 'Post_Link',
#        'Post_Title', 'Spam', 'Tunisia', 'Type', 'Month'],
#       dtype='object')

# %% [markdown]
# By observing the displayed Data Drame above, we quickly infer that features such as: `Lang_Prob`, `Spam`  and `Category` seem to add no meaning. In fact, information about category is already accessible in `Type`. Moreover, we verify, for the two remaining meaningless features, that they display a constant value:

# %%
#Verify values for meaningless columns
print(df.Lang_Prob.unique())
print(df.Spam.unique())
# Out:
# [-1]
# [0]

# %% [markdown]
# We drop the features hereafter:

# %%
#clean meaningless features
df = df.drop(['Lang_Prob', 'Spam'], axis = 1)

# %% [markdown]
# **Moreover**, we verify some **redundacy** in our df, since **the content of several entries is repeated**. Therefore, we deal with such repetitions:

# %%
#delete repetitions
for feature in ['Identifier', 'Post_Content']:
    df.drop_duplicates(feature, keep='first', inplace=True)

# %% [markdown]
# Let's verify that the values are now unique:

# %%
print(len(df.Identifier.unique()) == len(df), len(df.Post_Content.unique()) == len(df))
# Out:
# True True

# %% [markdown]
# Finally, the df **is cleaned**.
#
# We follow on with a **description of the `DataFrame` features**:
#
# - `Author_Link` - Contains a link to the author profile, in case of a Facebook Post, or his email adress. This information however is not always available.
# - `Author_Name` - Contains the name of the author
# - `Datetime` - Represents the Date and Time of a post, in a TimeStamp format
# - `Egypt` -  Represents the number of defined **keyphrases** (egyptian) in the post.
# - `Identifier`- Each post as an unique identifier
# - `Lang_Code` - Code of the language of the corresponding post
# - `Post_Content` - Content of the post
# - `Post_Link`- Link to the source of the post
# - `Post_Title`- Title of the post
# - `Tunisia`- Represents the number of defined **keyphrases** (tunisian) in the post.
# - `Type` - Type of post. Categorical feature that can take the following values: [`CLASSIFIED`, `FORUM`, `MAINSTREAM_NEWS`, `SOCIAL_MEDIA`]

# %% [markdown]
# ## 2.5. Data Analysis: Language and Post Type Distributions<a class="anchor" id="25"></a>

# %% [markdown]
# Having **cleaned** our data, we move on with the **analysis** of the collected information. We define thw following functions to analyse the resulting Dataframe:

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['text.color'] = 'k'
plt.rcParams['font.size'] = 12

def plot_pie_chart(pandas_object, show=False):
    """
    plots porportions as a pie chart given:
    :param pandas_object: Pandas Series or DF to plot
    :param show: boolean
    """
    # define labels and corresponding proportion
    try:
        labels = sorted(pandas_object.unique())
    except:
        labels = pandas_object.unique()
    proportions = [len(pandas_object[pandas_object == label])/len(pandas_object) for label in labels]
    
    # define a color map
    cmap = plt.get_cmap('Spectral')
    colors = cmap(np.linspace(0, 1, len(labels)))
    
    # explode 1st slice
    explode = [0 if proportion > .3 else .1 for proportion in proportions]
    
    plt.title('Proportion of items by {}'.format(pandas_object.name))
    plt.pie(proportions, explode=explode, labels=None, colors=colors[:len(proportions)],
        autopct='%1.1f%%', shadow=True, startangle=140, pctdistance=1.2)
    plt.legend(labels=labels, bbox_to_anchor=(1, 1))
    plt.axis('equal')
    if show:
        plt.show()

def plot_histogram(pandas_object, show=False, sort=False):
    """
    plots a histogram of the given pandas Series:
    :param pandas_object: Pandas Series or DF to plot
    :param show: boolean
    """
    
    values = pandas_object.value_counts()
    if sort: 
        values = values.sort_index()
        
    indexes = values.index
    y_pos = np.arange(len(indexes))
        
    # Bar plot
    rects = plt.bar(y_pos, values, align='center', alpha=0.5)
    autolabel(rects, 100/len(pandas_object)*values)
    plt.xticks(y_pos, indexes, rotation='vertical')
    plt.xlabel(pandas_object.name)
    plt.ylabel('Number of items')
    plt.title('Number of posts by {}'.format(pandas_object.name))
    plt.grid(axis='y')
    if show:
        plt.show()
        
def autolabel(rects, proportions):
    """
    Attach a text label above each bar displaying its proportion
    :param rects: rects generated by the bar function
    :param porportions: the porportion of each item
    """
    for rect, pro in zip(rects, proportions):
        if pro>1:
            plt.text(rect.get_x() + rect.get_width()/2., 1.01*rect.get_height(),
                '%.2f' % pro, ha='center', va='bottom')

# %% [markdown]
# We start by analyse how the collected post are **distributed among these dates**:

# %%
#define figures
plt.figure(figsize=(15,6));

# Plot number of post by month
plt.subplot(121);
plot_histogram(df['Month'], sort=True)

# Plot the proportion of posts in January and February
plt.subplot(122);
plot_pie_chart(df.apply(
    lambda row: row.Month if row.Month in [1,2] else 'Others', axis=1).rename('Months (Jan, Feb)'))
plt.show();

# %% [markdown]
# From the histogram above, representing the number of posts by Month, we observe that some few posts are **misclassified**, they don't belong neither to **January** nor to ** February**. Since they are negligible, (only 0.7% from the pie chart), and we are focusing in comparing these two dates only, we decieded to drop them for this **Milestone**.

# %% [markdown]
# It would also be interesting to observe how the post are **distributed by language**. Moreover, we want to analyse how types of posts are distributted as well. We plot the language and post type distributions in the following:

# %%
def plot_type_lang(df):
    """
    plots a histogram of languages and a pie chart of types
    :param df: the dataframe
    """
    plt.figure(figsize=(15,6))
    plt.subplot(122)
    plot_pie_chart(df['Type'])
    plt.subplot(121)
    plot_histogram(df['Lang_Code'])
    plt.show()

# %%
plot_type_lang(df);

# %% [markdown]
# **English** is clearly the dominant language in the dataset, with more than **86%**, followed by **Arabic (~10%)** and **French (~4%)**.
#
# Regarding the distribution of post's types, the majority of posts comes from **SOCIA_MEDIA (47.6%)** and **MAINSTREAM_NEWS (33.6%)**. Nearly **18.1%** are **FORUM posts**.

# %% [markdown]
# To conclude our global analysis, we define the following function to plot the distribution of the **keyphrases score** for oul filtered data:

# %%
def tn_egy_scater(df, title='', size=8):
    """
    Plots a scater plot of posts based on Tunisia and Egypt keyword scores.
    :param df: DataFrame
    """
    plt.figure(figsize=(size,size))
    plt.scatter(df.Tunisia, df.Egypt, s=50*np.ones_like(df.Tunisia), 
                c=['m' if x>0 else 'r' if x<0 else 'b' for x in df.Tunisia-df.Egypt], 
                alpha=0.1, marker='o', label="Post")
    plt.xlabel("Tunisia score")
    plt.ylabel("Egypt score")
    plt.legend()
    plt.title(title)
    x = np.arange(max(df.Tunisia))
    plt.plot(x,'--')
    plt.show()

tn_egy_scater(df)

# %% [markdown]
# ## 2.6. How different are Jan. 14 and Feb. 11 in Data Distributions?<a class="anchor" id="26"></a>

# %% [markdown]
# We start by making a comparison between the two collected dates (14-01-2011 and 11-02-2011), since they represent two different interesting points on time.
#
# **14-01-2011:** [Ben Ali quits after 23 yrs in power & leaves Tunisia](https://www.alarabiya.net/articles/2011/01/14/133432.html).
#
# **11-02-2011:** [Hosni Mubarak resigns as president](http://www.aljazeera.com/news/middleeast/2011/02/201121125158705862.html).
#
# Having collected data from this two dates, we are now ready to start our analysis.

# %% [markdown]
# ### 2.6.1. Language and Post Type Distributions<a class="anchor" id="261"></a>
#
# For **Jan. 14, 2011**, the day when **Tunisia**'s President resigned:

# %%
jan_df = df.loc[df.Month == 1]
plot_type_lang(df=jan_df)

# %% [markdown]
# For **Feb. 11, 2011**, the day when **Egypt**'s President resigned:

# %%
feb_df = df.loc[df.Month == 2]
plot_type_lang(df=feb_df)

# %% [markdown]
# **Observations:**
#
# - **Post Type Distribution:** We notice that both dates contain a negligible amount of the type `CLASSIFIED`. However, whereas the distributions in `NEWS`, `SOCIAL_MEDIA` and `FORUM` are close to equal for Jan. 14, over half of the shares of posts are `SOCIAL_MEDIA` posts for Feb. 11, and there are less `FORUM` posts.
#
# - **Language Distribution:** The distribution of languages is overall skewed to English for both, but more so for Feb. 11. Given the fact that Tunisia has a large francophone population, there is more French-language data for Jan. 14. Likewise, Egypt has a large English-speaking population, and that could explain the fact that English has a larger share in Feb. 11.

# %% [markdown]
# ### 2.6.2. Country Distributions<a class="anchor" id="262"></a>
#
# For **Jan. 14, 2011**, the day when **Tunisia**'s President resigned:

# %%
tn_egy_scater(df=jan_df)

# %% [markdown]
# For **Feb. 11, 2011**, the day when **Egypt**'s President resigned:

# %%
tn_egy_scater(feb_df)

# %% [markdown]
# **Observations:**
#
# We notice that our keyphrases were effective in choosing the data, as we see that the distribution gets skewed towards the country where the presidential resignation is happening on both dates.

# %% [markdown]
# ## 2.7. Keyword Detection by Language and Post Type<a class="anchor" id="27"></a>
#
# To get a more insightful experience of these two months, we compare what were the **most common keywords** in each period. We will use the text data in the Post Titles, corresponding to the column `Post_Title`.
#
# ### 2.7.1. Keyword Extraction<a class="anchor" id="271"></a>
#
# We first make the two following functions to get keywords per language and post type:

# %%
def get_keywords_per_language(content, language):
    """
    Gets keywords for the given content as per its corresponding language.
    :param content: string
    :param language: string
    :return: list of strings
    """
    unigram_tokens = tokenize_without_stopwords(content, language)
    keywords = get_most_popular_tokens(unigram_tokens, 50)
    return keywords

def get_keywords_per_column(column):
    """
    Gets keywords per DataFrame column.
    :param row: DataFrame column
    :return: list of lists of strings
    """
    return [get_keywords_per_language(column[multi_index], CODE_TO_LANG[multi_index[1]]) 
            for multi_index in column.index]

# %% [markdown]
# We put the keywords in the following `DataFrame`:

# %%
keywords_per_type_lang = df[(df.Month.isin([1,2])) & (df.Type != 'CLASSIFIED')].groupby(
    ['Month', 'Lang_Code', 'Type'])[['Post_Title']].agg(
    lambda texts: ' '.join(texts)).unstack().apply(get_keywords_per_column)
keywords_per_type_lang
# Out:
#                                                         Post_Title  \
# Type                                                         FORUM
# Month Lang_Code
# 1     ar         [تونس, الرئيس, الله, التونسي, محمد, مصر, العاب...
#       en         [½ï, new, tunisia, video, government, repack, ...
#       fr         [re, sydney, tunisie, ben, ali, janvier, urgen...
# 2     ar         [مبارك, مصر, الرئيس, التحرير, الله, الشعب, الج...
#       en         [mubarak, egypt, financial, analysis, online, ...
#       fr         [re, a, ligne, informations, comment, site, gu...
#
#                                                                     \
# Type                                               MAINSTREAM_NEWS
# Month Lang_Code
# 1     ar         [تونس, وفرار, الفقر, لتونس, بأكثر, الاتصالات, ...
#       en         [tunisia, president, tunisian, government, pro...
#       fr         [ben, tunisie, ali, a, président, gouvernement...
# 2     ar         [مبارك, مصر, المصري, الشعب, الرئيس, الجيش, الم...
#       en         [mubarak, egypt, egyptian, protesters, power, ...
#       fr         [moubarak, egypte, hosni, caire, manifestants,...
#
#
# Type                                                  SOCIAL_MEDIA
# Month Lang_Code
# 1     ar         [تونس, التونسي, الشعب, http, البلاد, محمد, زين...
#       en         [people, police, tunisia, many, power, governm...
#       fr         [a, tunisie, ali, ben, http, président, pays, ...
# 2     ar         [مبارك, الثورة, مصر, الرئيس, الشعب, http, com,...
#       en         [people, mubarak, egypt, egyptian, power, pres...
#       fr         [moubarak, a, président, egypte, hosni, http, ...

# %% [markdown]
# ### 2.7.2. Keywords on January 14<a class="anchor" id="272"></a>
#
# The following are the keywords on Jan. 14 for `MAINSTREAM_NEWS` and `SOCIAL MEDIA` in English:

# %%
keywords_per_type_lang.loc[(1, 'en')]['Post_Title']['MAINSTREAM_NEWS'][:10]
# Out:
# ['tunisia',
#  'president',
#  'tunisian',
#  'government',
#  'protests',
#  'new',
#  'police',
#  'ali',
#  'ben',
#  'power']

# %%
keywords_per_type_lang.loc[(1, 'en')]['Post_Title']['SOCIAL_MEDIA'][:10]
# Out:
# ['people',
#  'police',
#  'tunisia',
#  'many',
#  'power',
#  'government',
#  'officers',
#  'president',
#  'tunisian',
#  'officer']

# %% [markdown]
# **Observation**
#
# We see that the text data is dominated by talk about Tunisia. We notice less formality in Social Media, as there is talk about *people* rather than *protesters*. But overall, there is a consistency in the keywords.

# %% [markdown]
# ### 2.7.3. Keywords on February 11<a class="anchor" id="273"></a>
#
# The following are the keywords on Jan. 14 for `MAINSTREAM_NEWS` and `SOCIAL MEDIA` in English:

# %%
keywords_per_type_lang.loc[(2, 'en')]['Post_Title']['MAINSTREAM_NEWS'][:10]
# Out:
# ['mubarak',
#  'egypt',
#  'egyptian',
#  'protesters',
#  'power',
#  'president',
#  'obama',
#  'military',
#  'hosni',
#  'steps']

# %%
keywords_per_type_lang.loc[(2, 'en')]['Post_Title']['SOCIAL_MEDIA'][:10]
# Out:
# ['people',
#  'mubarak',
#  'egypt',
#  'egyptian',
#  'power',
#  'president',
#  'hosni',
#  'government',
#  'military',
#  'revolution']

# %% [markdown]
# **Observation**
#
# Here, the dominant topic is Egypt. We notice the same phenomenon about formality across post types, and keywords remain consistent.

# %% [markdown]
# # 3. Gauging the Accuracy of the Keyphrases<a class="anchor" id="3"></a>
#
# In order to check how accurate the keywords approach is, we decided to scrap some articles related to the Tunisian and Egyptian Revolutions from the **DW (Deutsche Welle)** website. It is Germany's public international broadcaster. The website is available in different languages including English, Arabic and French.
#
# We scraped 100 articles for each language and using the corresponding keyphrase for Egypt and Tunisia respectively (table below).
#
# | Country | Language | Keyphrase            |
# |---------|----------|----------------------|
# |         | English  | Egyptian Revolution  |
# | Egypt   | French   | Révolution égyptienne|
# |         | Arabic   | الثورة المصرية            |
# |         |          |                      |
# |         | English  | Tunisian Revolution  |
# | Tunisia | French   | Révolution tunisienne|
# |         | Arabic   | الثورة التونسية            |
#
# ## 3.1. Scraping Deutsche Welle Articles on the Tunisian and Egyptian Revolutions<a class="anchor" id="31"></a>
#
# We use the following functions to scrape DW:

# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = 'http://www.dw.com/'
URL = "http://www.dw.com/search/?languageCode=en&item=tunisian%20revolution&searchNavigationId=9097-1452-32771-2469-30687-101618-8120&sort=RELEVANCE&resultsCounter=100"

def write_to_file(data, filename, sep='\n\n\n'):
    """
    Writes articles to txt file
    :param data: list of strings, list of articles
    :param filename: String
    :param sep: separator
    """
    file = open('dw/{}.txt'.format(filename), 'w', encoding='utf-8') 
    for d in data:
        file.write(d + sep)
    file.close()
    print('    The file contaning {} articles has been successfully created in : ./dw/{}.txt'.format(
        len(data), filename))

def get_links(keyword, lang, num_art, rev_period):
    """
    Scrape the list of links of articles corresponding to the keyword
    :param keyword: string
    :param lang: string, language
    :param num_art: int, number of links
    :param rev_period: string, revolution period if True, take period from January 11 to February 14
    :return: string list, list of links
    """
    BASE_URL = 'http://www.dw.com/'
    URL = BASE_URL + "search/?languageCode={}&item={}&sort=RELEVANCE&resultsCounter={}".format(
        lang, keyword.replace(' ', '%20'), num_art)
    if rev_period:
        from_ = '01.01.2011'
        to_ = '01.01.2012'
        URL += "&from={}&to={}".format(from_, to_)
    r = requests.get(URL)
    page_body = r.text
    soup = BeautifulSoup(page_body, 'html.parser')
    div = soup.find_all('div', 'searchResult')
    links = []
    for d in div:
        links.append(d.find('a')['href'])
    return links

def get_article(link):
    """
    Scrape article from a given link
    :param link: string
    :return: string, article
    """
    URL = BASE_URL + link
    r = requests.get(URL)
    page_body = r.text
    soup = BeautifulSoup(page_body, 'html.parser')    
    content = []
    
    title = soup.find('h1')
    if title != None:
        content.append(title.text.strip())
    try:
        content.append(soup.find_all('p', 'intro')[0].text.strip())
    except IndexError:
        pass
    
    par = soup.find_all('div', 'longText')
    if len(par)>0:
        par = par[0].find_all('p')
        for i in range(len(par)):
            if par[i].find('span') == None:
                content.append(par[i].text.strip())
    return ' '.join(content)

def dw_scraper(keyword, lang=EN, num_art=400, rev_period = False, filename=None):
    """
    Scrapes articles from DW website
    :param keyword: string, search query
    :param num_art: int, number of articles to scrape
    :param rev_period: string, revolution period if True, take period from January 11 to February 14
    :param filename: string
    :return: string list, list of scraped articles
    """
    links = get_links(keyword, lang[:2], num_art, rev_period)
    keyword_articles = []
    for link in links:
        keyword_articles.append(get_article(link))
    if filename != None:
        write_to_file(keyword_articles, filename + "_" + lang)
    return keyword_articles

# %% [markdown]
# The following keyphrases are the ones used for searching articles, as defined in the table above:

# %%
DW_KEYSEARCH = WIKI_ARTICLES.copy()
DW_KEYSEARCH[EG][EN] = 'Egyptian Revolution'
DW_KEYSEARCH[EG][FR] = 'Révolution égyptienne'
DW_KEYSEARCH[EG][AR] = 'الثورة المصرية'

# %% [markdown]
# We scrape articles for Tunisia and Egypt's revolutions:

# %%
DW_ARTICLES = {}
for country in DW_KEYSEARCH:
    print('Scraping articles for {} ...'.format(country))
    country_articles = {}
    for lang, keyword in DW_KEYSEARCH[country].items():
        country_articles[lang] = dw_scraper(keyword, lang, filename=country)
    DW_ARTICLES[country] = country_articles
# Out:
# Scraping articles for Tunisia ...
#     The file contaning 87 articles has been successfully created in : ./dw/Tunisia_french.txt
#     The file contaning 229 articles has been successfully created in : ./dw/Tunisia_english.txt
#     The file contaning 400 articles has been successfully created in : ./dw/Tunisia_arabic.txt
# Scraping articles for Egypt ...
#     The file contaning 132 articles has been successfully created in : ./dw/Egypt_french.txt
#     The file contaning 400 articles has been successfully created in : ./dw/Egypt_english.txt
#     The file contaning 400 articles has been successfully created in : ./dw/Egypt_arabic.txt

# %% [markdown]
# ## 3.2. Article Classification Approach<a class="anchor" id="32"></a>
#
# The classification is to assign a country (`Egypt` or `Tunisia`) to a given Deutsche Welle article using the corresponding keyphrases extracted from Wikipedia. We compute the keyphrase score for a given article in its language. Then, we assign it to a country if the score is positive and higher than or equal to the other country's score.
#
# We use the following function to classify:

# %%
def compute_accuracy(articles, language, country):
    """
    Computes the accuracy of the keyphrase approach
    :param articles: list of strings, list of articles
    :param language: string
    :param country: string, country label
    :return: float, the accuracy
    """
    count = {TN: 0, EG: 0}
    idx = 1
    for article in articles:
        scores = compute_keyphrase_scores(article.lower(), language)
        if not scores:
            scores = {TN: 0, EG: 0} 
        tun = scores[TN]
        egy = scores[EG]
        idx += 1
        if tun >= egy and tun > 0:
            count[TN] += 1
        if tun <= egy and egy > 0:
            count[EG] += 1
    accuracy = count[country]/len(articles)
    print("The accuracy for {}'s articles in {} is {}%".format(country, language, round(100*accuracy, 2)))
    return accuracy

# %% [markdown]
# ## 3.3. Classifying the DW Articles by Country<a class="anchor" id="33"></a>
#
# We compute the accuracy in the following:

# %%
articles_accuracy = {}
for country in DW_ARTICLES:
    country_accuracy = {}
    for lang, articles in DW_ARTICLES[country].items():
        country_accuracy[lang] = compute_accuracy(articles, lang, country)
    articles_accuracy[country] = country_accuracy
# Out:
# The accuracy for Tunisia's articles in english is 90.83%
# The accuracy for Tunisia's articles in french is 65.52%
# The accuracy for Tunisia's articles in arabic is 85.5%
# The accuracy for Egypt's articles in english is 93.25%
# The accuracy for Egypt's articles in french is 90.91%
# The accuracy for Egypt's articles in arabic is 78.0%

# %% [markdown]
# We visualise the accuracy of the Keyphrase Method:

# %%
pd.DataFrame(articles_accuracy).T.plot.barh(
    title='Accuracy of the Keyphrase Method on DW Articles by Country and Language\n');
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# **Conclusion:**
#
# The articles show that overall **the accuracy of document classification by using Wikipedia articles is high**. No accuracy is below 65% and **this experiment validates our classification method**.

# %% [markdown]
# # 4. Extracting and Filtering the 2.1 TB of `Spinn3r` data<a class="anchor" id="4"></a>
#
# ## 4.1. Using the Cluster<a class="anchor" id="41"></a>
#
# We extracted and filtered the data using `pyspark` and the following methods:
# 1. a modified version of `read_protostream_file` as a function argument to `map`. This modified version returns a `dict` if the entry passes the filtering, or an empty array otherwise. The filtering uses the following methods:
# 2. `keyphrase_score` to compute the score for a given article
# 3. `compute_keyphrase_scores` to filter by country score
# 4. a new function `check_datetime` to ensure that we are within the defined time frame of Jan. 13 to Feb. 14 of the year 2011. It is defined as follows:

# %%
def check_datetime(datetime):
    """
    Checks if date given is within range of days studied: Jan 13, 2011 to Feb 14, 2011, included.
    :param datetime: string
    :return: boolean
    """
    try:
        year = int(datetime[:4])
        month = int(datetime[5:7])
        day = int(datetime[8:10])
        return year == 2011 and ((month == 1 and day in range(13,32)) 
                                 or (month == 2 and day in range(1,15)))
    except:
        return False

# %% [markdown]
# We output the results as a distributed pickle file. We copied it locally.
#
# ## 4.2. Handling the Distributed Pickle File Locally<a class="anchor" id="42"></a>
#
# We use the following program, distributed over the cores using the `joblib` package, to transform the distributed pickle file into 20 `DataFrames` saved as pickle files:

# %%
import os
from os import listdir
import sparkpickle
import pandas as pd
import time
import joblib
import pickle
import numpy as np
from joblib import Parallel, delayed
import multiprocessing

def load_files(files):
    """
    Loads parts of the distributed pickle file and saves it.
    Job function.
    :param files: list of strings
    """
    print(time.ctime(), '    Start...')
    data = []
    for file in files:
        for obj in sparkpickle.load_gen(open('data.pkl/{}'.format(file), 'rb')):
                data.append(obj)
    print(time.ctime(), '    Loading DF...')
    df = pd.DataFrame(data)
    print(time.ctime(), '    Loaded DF. Saving...')
    del data
    df.to_pickle('dataframes/df.{}.pkl'.format(time.time()))
    print(time.ctime(), '    Saved.')
    del df

def main():
    """
    Main method.
    Iterates in parallel over 20 jobs on the distributed pickle file.
    """
    files = [file for file in listdir('data.pkl') if file.startswith('part')]

    print(time.ctime(), 'Starting...')

    njobs = 20
    files_range = np.array_split(files, njobs)

    Parallel(n_jobs=njobs, verbose=11)(delayed(load_files)(f) for f in files_range)

    print(time.ctime(), 'Done ...')

if __name__ == '__main__':
    main()

# %% [markdown]
# The saved `DataFrames` accumulate to about **a size of 9GB**.
#
# ## 4.3. Loading and Cleaning the `DataFrames`<a class="anchor" id="43"></a>
#
# We load all of the `DataFrames` from the 20 pickle files using the following function:

# %%
from os import listdir

def load_pickled_df(path, prefix, path_prefix='/Users/Khalil/Desktop/data/data.pkl/'):
    """
    Loads DataFrame from series of pickle files.
    :param path: string, directory path
    :param prefix: string, file prefix
    :return: DataFrame
    """
    path = path_prefix + path
    dfs = []
    files = [file for file in listdir(path) if file.startswith(prefix)]
    total = len(files)
    for index, file in enumerate(files):
        print('Loading DataFrame from file {} from {} '.format(index, file), flush=True, end='\r')
        dfs.append(pd.read_pickle(path + file))
    print('Concatenating the Pickled DataFrames...   ', flush=True, end='\r')
    df = pd.concat(dfs)
    print('Loaded all the DataFrames as one.         ', flush=True, end='\r')
    return df

# %% [markdown]
# Loading the `DataFrame`:

# %%
df = load_pickled_df('dataframes/', 'df')
df.head()
# Out:
# Loading DataFrame from file 19 out of df_9.pkll
#         Author_Name              Datetime  Egypt           Identifier  \
# 0     رزاق الجزائري  2011-01-18T16:11:44Z      2  1295429123234078242
# 1        ابوالروابي  2011-01-16T10:19:00Z      4  1295429124234078225
# 2  محمد محمد البقاش  2011-01-16T12:47:54Z     11  1295429124234078226
# 3          محمد يوب  2011-01-15T19:31:22Z      9  1295429124234078244
# 4       بنت المدينة  2011-01-14T15:06:12Z      5  1295429125234078225
#
#   Lang_Code                                       Post_Content  \
# 0        ar  سقط نظام بن علي في تونس وتوقفت الأنفاس مشدوهة ...
# 1        ar  كنت شعلة اللهب\nذات يوم أصبح تاريخا\nللثوار وا...
# 2        ar  هل يسلم الملك عبد الله زين العابدين إلى الشعب ...
# 3        ar   حدود السرد وحدود السيناريو في "كائنات من غبار...
# 4        ar  السلام عليكم ورحمة الله وبركاته\n\nفاتنة أنتِ،...
#
#                                            Post_Link  \
# 0  http://merbad.net/vb/showthread.php/18067-درس-...
# 1  http://merbad.net/vb/showthread.php/18058-رسال...
# 2  http://merbad.net/vb/showthread.php/18060-هل-ي...
# 3  http://merbad.net/vb/showthread.php/18052-حدود...
# 4  http://merbad.net/vb/showthread.php/18045-فاتن...
#
#                                           Post_Title  Tunisia    Type
# 0                     درس تونس للشعوب والنظم العربية        7  WEBLOG
# 1  رسالة إلى محمد  البوعزيزي في قبره    شعر عزالد...        6  WEBLOG
# 2  هل يسلم الملك عبد الله زين العابدين إلى الشعب ...       19  WEBLOG
# 3  حدود السرد  وحدود السيناريو في "كائنات من غبار...        6  WEBLOG
# 4                                          فاتنة أنت        1  WEBLOG

# %% [markdown]
# We saw that the `WEBLOG` category is the overwhelming part of the posts. Moreover, it has a large body of texts compared to `SOCIAL_MEDIA`. We filter it further by putting the threshold of the sum of keyphrase scores at a higher value. This will help to get a **higher quality** of posts.

# %%
mask = (df.Type == 'WEBLOG')
df = df[(mask & (df.Tunisia + df.Egypt >= 12)) | (~mask)]

# %% [markdown]
# We do the same for `MAINSTREAM_NEWS` as it also has a larger amount of text:

# %%
mask = (df.Type == 'MAINSTREAM_NEWS')
df = df[(mask & (df.Tunisia + df.Egypt >= 8)) | (~mask)]

# %% [markdown]
# The `CLASSIFIED` and `REVIEW` types have an insignificant number of posts, and so we remove them:

# %%
df = df[~df.Type.isin(['CLASSIFIED', 'REVIEW'])]

# %% [markdown]
# Below we count how many posts there are per language and per post type.

# %%
df.groupby(['Type', 'Lang_Code'])['Lang_Code'].count().unstack().fillna(0).applymap(int)
# Out:
# Lang_Code           ar      en     fr
# Type
# FORUM            45287   46363   2423
# MAINSTREAM_NEWS    836  168518   4012
# SOCIAL_MEDIA     14244  116297   8199
# WEBLOG           21818  148643  30607

# %% [markdown]
# To be able to perform Time Series Analysis, we add a column for days:

# %%
df['Day'] = df.Datetime.apply(lambda datetime: datetime[:10])

# %% [markdown]
# ## 4.4. Splitting by Country<a class="anchor" id="44"></a>
#
# We split the data by country using the keyphrase scores:

# %%
eg_df = df[df.Egypt >= df.Tunisia]
tn_df = df[df.Tunisia >= df.Egypt]

# %% [markdown]
# We use the following function to provide counts and distribution visualisations:

# %%
def count_and_plot(df):
    """
    Provides counts and distribution visualisations for a given DataFrame.
    :param df: DataFrame
    :return: DataFrame
    """
    plot_type_lang(df)
    count_df = df.groupby(['Type', 'Lang_Code'])['Lang_Code'].count().unstack().applymap(int)
    count_df = count_df.append(pd.Series(count_df.sum(), name='Total'))
    count_df = pd.concat([count_df, pd.Series(count_df.sum(axis=1), name='Total')], axis=1)
    return count_df.applymap(lambda x: "{:,}".format(x))

# %% [markdown]
# ### 4.4.1. Egypt Statistics<a class="anchor" id="441"></a>

# %%
count_and_plot(eg_df)
# Out:
#                      ar       en      fr    Total
# Type
# FORUM            31,253   31,200   1,455   63,908
# MAINSTREAM_NEWS     458  132,225   2,140  134,823
# SOCIAL_MEDIA      7,627   89,015   4,361  101,003
# WEBLOG           13,744  119,078  23,878  156,700
# Total            53,082  371,518  31,834  456,434

# %% [markdown]
# **Observation:** We notice that the post types are evenly balanced. A non-negligible part of the posts are **not** in English (about 20%).

# %% [markdown]
# ### 4.4.2. Tunisia Statistics<a class="anchor" id="442"></a>

# %%
count_and_plot(tn_df)
# Out:
#                      ar       en      fr    Total
# Type
# FORUM            19,156   22,090   1,387   42,633
# MAINSTREAM_NEWS     457   56,907   2,496   59,860
# SOCIAL_MEDIA      8,186   34,839   4,695   47,720
# WEBLOG           10,052   41,559  10,224   61,835
# Total            37,851  155,395  18,802  212,048

# %% [markdown]
# **Observation:** Likewise, post types are evenly balanced, and about the same proportion is not in English.
#
# ## 4.5. Distribution of Posts over Days<a class="anchor" id="45"></a>
#
# We compute the distribution of posts over days for both countries.
#
# We use the following function to plot it:

# %%
def plot_time_series(df, max_, country):
    """
    Plotting the time series for a given dataframe.
    :param df: DataFrame
    :param max_: int
    :param country: string
    """
    title = 'Distribution over time of posts concerning {}'.format(country)
    df.groupby(['Day', 'Type'])['Identifier'].count().unstack().plot.line(figsize=(13,5), lw=2, 
                                                                          title=title);
    plt.ylabel('Number of Posts')
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));
    line_details = {1: ['b', 'Tunisian President Resigns'],
                    4: ['g', 'New Tunisian Cabinet Announced'],
                    12: ['r', 'Egyptian Revolution Begins'],
                    15: ['m', 'Day of Rage in Egypt'],
                    29: ['y', 'Egyptian President Resigns']}
    for index in line_details:
        plt.axvline(index, color=line_details[index][0], lw=2);
        plt.text(index + 0.1, max_, line_details[index][1],rotation=90, verticalalignment='top');

# %% [markdown]
# ### 4.5.1. Egypt Time Series<a class="anchor" id="451"></a>

# %%
plot_time_series(eg_df, 12000, EG)

# %% [markdown]
# **Observation:** We notice that the data is skewed towards the right side of the time series, when the Egyptian revolution occurred. We have peaks at important peaks at the start of the revolution, as wel as when the President resigns. There is a heightened number of posts in all categories in the beginning of February, when the main protests happened.
#
# ### 4.5.2. Tunisia Time Series<a class="anchor" id="452"></a>

# %%
plot_time_series(tn_df, 4500, TN)

# %% [markdown]
# **Observation:** The data is skewed towards the left side of the time series, when the Tunisian revolution was enaring the end. The number of posts concerning Tunisia rose during the beginning of the Egyptian revolution, showing the causal relationship the events in Tunisia have with the ones unfolding in Egypt.

# %% [markdown]
# # 5. Topic Detection<a class="anchor" id="5"></a>
#
# To follow on with the analysis, topic detection represents a more meaningful source of data, because of the information we can pick from the *latent features*.<br>
# - We start by defining the number of topics that we want to apply when clustering our data.<br>
# - After clustering, we can infer the thematic associated with a specific topic by **evaluating the words that influence that topic the most**.<br>
#
# ## 5.1. Preprocessing All Posts<a class="anchor" id="51"></a>
#
# ### 5.1.1. Tokenizing, Removing Stop Words and Internet Links<a class="anchor" id="511"></a>

# %%
import re
REGEX = r'(ftp:\/\/|www\.|https?:\/\/){1}[a-zA-Z0-9u00a1-\uffff0-]{2,}\.[a-zA-Z0-9u00a1-\uffff0-]{2,}(\S*)'

def preprocess_posts(row):
    """
    Preprocesses by tokenizing and removing stop words and internet links, shows progression over indexes.
    :param row: Series
    :return: string
    """
    print('Preprocessing Row {}'.format(row.name), flush=True, end='\r')
    text = str(row.Post_Title) + ' ' + str(row.Post_Content)
    text = re.sub(REGEX, '', text)
    return tokenize_without_stopwords(text, CODE_TO_LANG[row.Lang_Code])

# %%
df['Tokens'] = df.apply(preprocess_posts, axis=1)
# Out:
# Preprocessing Row 112777

# %% [markdown]
# After preprocessing, we no longer need the `Post_Content` and `Post_Title` columns:

# %%
df.drop(columns=['Post_Content', 'Post_Title'], inplace=True)

# %% [markdown]
# Due to the demanding computing power of the above, we run it using the `joblib` library locally. We reload the `DataFrame` in the following:

# %%
df = load_pickled_df('preproc/', 'preproc')
df.head()
# Out:
#          Author_Name              Datetime  Egypt           Identifier  \
# 2   محمد محمد البقاش  2011-01-16T12:47:54Z     11  1295429124234078226
# 3           محمد يوب  2011-01-15T19:31:22Z      9  1295429124234078244
# 18                    2011-01-19T19:10:27Z      7  1295477503209436708
# 20                    2011-01-19T19:13:03Z      7  1295477503209436730
# 22                    2011-01-19T18:25:28Z      4  1295477504209436683
#
#    Lang_Code                                          Post_Link  Tunisia  \
# 2         ar  http://merbad.net/vb/showthread.php/18060-هل-ي...       19
# 3         ar  http://merbad.net/vb/showthread.php/18052-حدود...        6
# 18        ar  http://www.arabicdream.com/topic/71930-%d8%a7%...        8
# 20        ar  http://www.arabicdream.com/topic/71932-%d8%a7%...        8
# 22        ar  http://www.arabicdream.com/topic/71941-%d9%86%...        9
#
#       Type         Day                                             Tokens
# 2   WEBLOG  2011-01-16  [يسلم, الملك, عبد, الله, زين, العابدين, الشعب,...
# 3   WEBLOG  2011-01-15  [حدود, السرد, وحدود, السيناريو, كائنات, غبار, ...
# 18  WEBLOG  2011-01-19  [الرئيس, العراقي, وإسباغ, الشرعية, قاتل, الرئي...
# 20  WEBLOG  2011-01-19  [الرئيس, العراقي, وإسباغ, الشرعية, قاتل, الرئي...
# 22  WEBLOG  2011-01-19  [نجاد, يبشر, بجمهورية, اسلامية, تونسية, العرب,...

# %% [markdown]
# We save the `DataFrame` by language and post type:

# %%
POST_TYPES = list(df.Type.unique())
for post_type in POST_TYPES:
    for lang in LANGS:
        print('Saving for {} in {}              '.format(post_type, lang), flush=True, end='\r')
        df[(df.Type == post_type) & (df.Lang_Code == lang[:2])].to_pickle('data/{}_{}.pkl'.format(post_type, lang[:2]))
# Out:
# Saving for MAINSTREAM_NEWS in arabic

# %% [markdown]
# We clear the memory:

# %%
del df
del eg_df
del tn_df

# %% [markdown]
# ### 5.1.2. Adding Bigrams<a class="anchor" id="512"></a>
#
# We saw in parts [4.4.1](#441) and [4.4.2](#442) that there are differences in sizes of the languages. Moreover, each of the post types and languages use different vocabularies, and as such we don't want the bigrams of a given post type or language to hamper the formation of bigrams for smaller categories. We will use a **different bigram model for each language and post type**:

# %%
from gensim.models.phrases import Phrases, Phraser
files = [file for file in listdir('data') if file.endswith('.pkl')]
for file in files:
    print('Reading the Pickle File for {}...        '.format(file), flush=True, end='\r')
    df = pd.read_pickle('data/' + file)
    print('Forming the Bigram Model for {}...       '.format(file), flush=True, end='\r')
    bigram_model = Phraser(Phrases(sentences=list(df.Tokens)))
    print('Adding the Bigrams for {}...             '.format(file), flush=True, end='\r')
    df.Tokens = df.Tokens.apply(lambda tokens: bigram_model[tokens])
    print('Saving as Pickle File for {}...          '.format(file), flush=True, end='\r')
    df.to_pickle('bigram_data/{}'.format(file))
print('Done!                                                 ')

# %% [markdown]
# These operations are computationally expensive. Externally, we:
# 1. Compute a bigram model by language and post type
# 2. Apply it for each of the DataFrames
# 3. Save it to `pickle` files

# %%
from polyglot.text import Text
import re
import pandas as pd
GOOD_TAGS = set('ADJ NOUN PROPN X'.split())

def filter_per_row(tokens, language):
    """
    Filtering a set of tokens or returning them if error.
    :param tokens: list of strings
    :param language: string
    :return: list of strings
    """
    try:
        return [str(token) for token, pos
                in Text(' '.join(tokens), hint_language_code=language[:2]).pos_tags 
                if pos in GOOD_TAGS and len(token) > 2]
    except:
        return tokens

def pos_tag_filtering(post_type, language):
    """
    Filters based on PoS Tag for French and English, removing Latin characters from Arabic.
    Removes Short words.
    """
    print('Filtering for {}-language {}               '.format(
        language, post_type), flush=True, end='\r')
    df = pd.read_pickle('bigram_data/{}_{}.pkl'.format(post_type, language[:2]))
    if language in [EN, FR]:
        df.Tokens = df.Tokens.apply(lambda tokens: filter_per_row(tokens, language))
    if language == AR:
        df.Tokens = df.Tokens.apply(
                    lambda tokens: [token for token in tokens 
                            if re.search(r'[a-z]', token) == None and len(token) > 1])
    print('Saving DF for {}-language {}               '.format(
        language, post_type), flush=True, end='\r')
    df.to_pickle('preproc_data/{}_{}.pkl'.format(post_type, language[:2]))

# %%
for language in LANGS:
    for post_type in POST_TYPES:
        pos_tag_filtering(post_type, language)
# Out:
# Saving DF for english-language MAINSTREAM_NEWS

# %% [markdown]
# ## 5.2. Topic Detection Methods<a class="anchor" id="52"></a>
#
# In the following we build functions for our topic detection pipeline.
#
# ### 5.2.1. Bag-of-Words Representation<a class="anchor" id="521"></a>

# %%
from gensim import corpora
import gensim.models

def BOW(posts, no_below=20, no_above=0.5):
    """
    Creates a dictionary and BOW representation using gensim library
    :param posts: list of strings
    :param max_freq: int - do not consider too frequent words
    :param min_wordcout: int - minimium number of word counts to be considered
    :return: corpus_tfidf (TransformedCorpus), dictionary (indexes to words, dict)
    """
    dictionary = corpora.Dictionary(posts)
    # filter dictionary
    dictionary.filter_extremes(no_below=no_below, no_above=no_above)
    # filter out empty sentences
    corpus = [dictionary.doc2bow(post) for post in posts]
    # TF-IDF Model
    tfidf = gensim.models.TfidfModel(corpus)
    corpus_tfidf = tfidf[corpus]
    return corpus_tfidf, dictionary

# %% [markdown]
# ### 5.2.2. LSA Model<a class="anchor" id="522"></a>

# %%
from pprint import pprint
from gensim.models import LsiModel

def compute_LSA(corpus_tfidf, dictionary, n_topics=3, n_words=5):
    """
    Shows the 5 most meaningful words for 3 topics found using a LSA Model.
    :param corpus_tfidf: TransformedCorpus
    :param dictionary: dict
    :param n_topics: int
    :param n_words: int
    """
    topics = LsiModel(corpus_tfidf,
                      id2word=dictionary, 
                      num_topics=n_topics).show_topics(num_words=n_words)
    index = 0
    for topic_list in topics:
        index += 1
        print('Most meaningful words of topic {}:'.format(index))
        pprint(topic_list)
    print('\n')

# %% [markdown]
# ### 5.2.3. LDA Model<a class="anchor" id="523"></a>

# %%
from gensim.models import LdaModel
import numpy as np
np.seterr(invalid='warn')
import pyLDAvis
import pyLDAvis.gensim
import warnings
warnings.filterwarnings('ignore')

def compute_LDA(corpus_tfidf, dictionary, filename, n_topics=3, n_words=5, show=True):
    """
    Shows the 5 most meaningful words for 3 topics found using a LSA Model.
    :param corpus_tfidf: TransformedCorpus
    :param dictionary: dict
    :param filename: string
    :param n_topics: int
    :param n_words: int
    """
    np.random.seed(7)
    model_Lda = LdaModel(corpus=corpus_tfidf, 
                         num_topics=n_topics, 
                         id2word=dictionary,
                         )
    if show:
        topics = model_Lda.show_topics(num_words=n_words)
        index = 0
        for topic_list in topics:
            index += 1
            print('Most meaningful words of topic {}:'.format(index))
            pprint(topic_list)
        print('\n')
    pyLDAvis.save_html(pyLDAvis.gensim.prepare(model_Lda, corpus_tfidf, dictionary), 
                       'pyLDAvis/{}.html'.format(filename))
    topic_distribution = [model_Lda.get_document_topics(post) for post in corpus_tfidf]
    return topic_distribution

# %% [markdown]
# ## 5.3. Showcase of Topic Modelling Results<a class="anchor" id="53"></a>
#
# Since there are 24 possible cases (2 countries, 4 post types, 3 languages), we will showcase a few cases for topic modelling. We use the following function:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def showcase_topic_modelling(country, post_type, language, n_topics=3, LSA=True, no_above=0.5, no_below=20):
    """
    Shows a case of topic modelling.
    :param country: string
    :param post_type: string
    :param language: string
    """
    df = pd.read_pickle('preproc_data/{}_{}.pkl'.format(post_type, language[:2]))
    other_country = EG
    if country == EG:
        other_country = TN
    df = df[(df[country] >= df[other_country])]
    df.reset_index(inplace=True, drop=True)
    posts = list(df.Tokens)
    corpus_tfidf, dictionary = BOW(posts, no_below=no_below, no_above=no_above)
    
    # LSA
    if LSA:
        print('+++++++++++++++++++\n'
              'The LSA model:\n'
              '+++++++++++++++++++\n')
        compute_LSA(corpus_tfidf, dictionary, n_topics=n_topics)
    
    # LDA
    print('+++++++++++++++++++\n'
          'The LDA model:\n'
          '+++++++++++++++++++\n')
    topic_distribution = compute_LDA(corpus_tfidf, dictionary, 
                                     '{}_{}_{}_{}_{}_{}'.format(country, post_type, language, 
                                                                n_topics, no_below, no_above), 
                                     n_topics=n_topics, show=LSA)
    
    length = len(topic_distribution)
    print('Number of posts:', length)
    topic_df = pd.DataFrame([dict(single_topic_dist) for single_topic_dist in topic_distribution]).fillna(0)
    return pd.concat([df, topic_df], axis=1)

# %% [markdown]
# ### 5.3.1. Egypt, Arabic, Forum<a class="anchor" id="531"></a>

# %%
showcase_topic_modelling(EG, 'WEBLOG', EN, LSA=False, n_topics=6, no_below=50)

# %% [markdown]
# ### 5.3.2. Egypt, English, Social Media<a class="anchor" id="532"></a>

# %%
showcase_topic_modelling(EG, 'SOCIAL_MEDIA', EN)
# Out:
# +++++++++++++++++++
# The LSA model:
# +++++++++++++++++++
#
# Most meaningful words of topic 1:
# (0,
#  '0.247*"people" + 0.242*"mubarak" + 0.238*"egyptian" + 0.225*"egypt" + '
#  '0.183*"protesters"')
# Most meaningful words of topic 2:
# (1,
#  '-0.662*"revolution_diplomatic" + -0.662*"car_ran" + -0.261*"cairo" + '
#  '-0.099*"people" + -0.081*"egyptian"')
# Most meaningful words of topic 3:
# (2,
#  '-0.301*"protesters" + -0.259*"president_hosni" + 0.255*"people" + '
#  '-0.249*"cairo" + -0.221*"mubarak"')
#
#
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Most meaningful words of topic 1:
# (0,
#  '0.040*"revolution_diplomatic" + 0.040*"car_ran" + 0.028*"cairo" + '
#  '0.015*"egyptian" + 0.012*"protesters"')
# Most meaningful words of topic 2:
# (1,
#  '0.004*"international" + 0.003*"many" + 0.003*"video" + 0.003*"government" + '
#  '0.003*"egypt"')
# Most meaningful words of topic 3:
# (2,
#  '0.007*"people" + 0.006*"government" + 0.005*"egypt" + 0.005*"egyptian" + '
#  '0.004*"mubarak"')

# %% [markdown]
# ### 5.3.3. Tunisia, English, News<a class="anchor" id="533"></a>

# %%
showcase_topic_modelling(TN, 'MAINSTREAM_NEWS', EN)

# %% [markdown]
# ### 5.3.4. Tunisia, French, Web Blogs<a class="anchor" id="534"></a>

# %%
showcase_topic_modelling(TN, 'WEBLOG', FR)

# %% [markdown]
# # Analyse here!

# %%
showcase_topic_modelling(EG, 'FORUM', FR, n_topics=6, LSA=False, no_above=0.5, no_below=50)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 1455
#                     Author_Name              Datetime  Egypt  \
# 0                                2011-01-25T17:51:52Z      5
# 1                                2011-01-25T17:51:52Z      5
# 2               simpleetsolaire  2011-01-25T19:31:32Z      3
# 3                       shanaar  2011-01-25T16:01:59Z      6
# 4                   ratsovechov  2011-01-25T15:03:28Z      3
# 5                                2011-01-25T22:33:55Z      4
# 6                                2011-01-25T22:34:59Z      4
# 7                  KillerMapper  2011-01-25T21:26:23Z      4
# 8                 dartagnan2010  2011-01-25T21:58:44Z      3
# 9                      eyezberg  2011-01-25T21:30:42Z      3
# 10                      FannyNZ  2011-01-24T23:43:44Z      4
# 11                       Fanny!  2011-01-25T00:01:29Z      3
# 12                        Tereh  2011-01-25T00:41:51Z      3
# 13                       Sojiro  2011-01-25T12:29:13Z      4
# 14                     FrilliGe  2011-01-25T02:57:35Z      3
# 15                     FrilliGe  2011-01-25T02:57:35Z      3
# 16                         news  2011-01-25T04:45:39Z      3
# 17                     FrilliGe  2011-01-25T02:57:35Z      3
# 18                       pluche  2011-01-25T11:13:57Z      3
# 19                         news  2011-01-25T21:40:52Z      5
# 20                 KillerMapper  2011-01-25T21:26:23Z      4
# 21                   ylcasinouu  2011-01-25T12:33:58Z      4
# 22                       MIMATA  2011-01-25T13:28:20Z      3
# 23                          Pie  2011-01-25T22:38:57Z      3
# 24                       zantas  2011-01-25T13:28:54Z      4
# 25                    Adeline13  2011-01-25T13:28:28Z      3
# 26                     eyezberg  2011-01-25T21:30:42Z      3
# 27                     eyezberg  2011-01-25T21:30:42Z      3
# 28                     MANU-DMZ  2011-01-25T23:01:23Z      5
# 29                    Nightmare  2011-01-25T22:52:20Z      6
# ...                         ...                   ...    ...
# 1425               Shane Fenton  2011-01-21T19:26:15Z      4
# 1426            Captain_Cowkill  2011-01-21T17:58:02Z      3
# 1427                     mouzak  2011-01-21T13:40:54Z      4
# 1428                 dicasinoxb  2011-01-21T13:26:26Z      4
# 1429                    seb0886  2011-01-21T10:53:23Z      4
# 1430  flaroche@game-focus.com    2011-01-21T21:57:06Z      4
# 1431                laetilaeti7  2011-01-20T21:03:59Z      3
# 1432                   Melarnos  2011-01-20T13:50:33Z      6
# 1433                       worf  2011-01-21T08:18:25Z      3
# 1434                             2011-01-21T17:30:54Z      3
# 1435            Captain_Cowkill  2011-01-21T17:58:02Z      3
# 1436                    mum1989  2011-01-21T19:06:28Z      3
# 1437                             2011-01-21T15:00:17Z      3
# 1438                             2011-01-21T15:00:14Z      4
# 1439                 bourazzouq  2011-01-21T22:38:10Z      7
# 1440                        San  2011-01-21T17:32:00Z      3
# 1441                       news  2011-01-21T07:41:34Z      3
# 1442                        abc  2011-01-21T08:34:26Z      4
# 1443                        abc  2011-01-21T08:32:28Z      4
# 1444                        abc  2011-01-21T08:33:38Z      4
# 1445                        abc  2011-01-21T08:35:18Z      5
# 1446                   kentin08  2011-01-21T20:07:52Z      7
# 1447                             2011-01-21T17:50:54Z      3
# 1448                  framinoky  2011-01-21T20:56:19Z      4
# 1449                    nosocks  2011-01-21T00:32:24Z      5
# 1450                     SQUALL  2011-01-19T09:29:01Z      3
# 1451          Toshirô Hitsugaya  2011-01-19T14:03:49Z      4
# 1452                     SQUALL  2011-01-17T20:06:32Z      4
# 1453            chatouillesdu92  2011-01-17T18:16:24Z      7
# 1454                    nosocks  2011-01-15T17:58:30Z      4
#
#                Identifier Lang_Code  \
# 0     1295980646051249160        fr
# 1     1295980646051249161        fr
# 2     1295984698051249157        fr
# 3     1295965978047955978        fr
# 4     1295968557237387787        fr
# 5     1295995096011730952        fr
# 6     1295995096011730964        fr
# 7     1295995499097402910        fr
# 8     1295995562097402941        fr
# 9     1295997879097402884        fr
# 10    1295917145006537218        fr
# 11    1295917145006537219        fr
# 12    1295918277067010578        fr
# 13    1295927151206389303        fr
# 14    1295929284251396098        fr
# 15    1295929285251396110        fr
# 16    1295931119173178894        fr
# 17    1295931745035356674        fr
# 18    1295954447089243709        fr
# 19    1295992527089178119        fr
# 20    1295993499011730981        fr
# 21    1295961769147439620        fr
# 22    1295962879207159302        fr
# 23    1295963266098713671        fr
# 24    1295963770062226448        fr
# 25    1295964096077971457        fr
# 26    1295997879097402896        fr
# 27    1295997880097402880        fr
# 28    1295998625228769846        fr
# 29    1295999662180568070        fr
# ...                   ...       ...
# 1425  1295650559128335917        fr
# 1426  1295650560128335922        fr
# 1427  1295619968009781311        fr
# 1428  1295616613136232963        fr
# 1429  1295616901190234624        fr
# 1430  1295649036188383235        fr
# 1431  1295577119256213023        fr
# 1432  1295577677207667202        fr
# 1433  1295595699054968353        fr
# 1434  1295631198247332870        fr
# 1435  1295638001256720904        fr
# 1436  1295639068217038878        fr
# 1437  1295625811089243658        fr
# 1438  1295625820132808739        fr
# 1439  1295627504142901272        fr
# 1440  1295627505142901261        fr
# 1441  1295598751096829500        fr
# 1442  1295600489194969605        fr
# 1443  1295600489194969606        fr
# 1444  1295600489194969607        fr
# 1445  1295600489194969608        fr
# 1446  1295643779262504465        fr
# 1447  1295645515254836776        fr
# 1448  1295645662262504451        fr
# 1449  1295602875103776258        fr
# 1450  1295602878103776274        fr
# 1451  1295602878103776276        fr
# 1452  1295602882103776286        fr
# 1453  1295602882103776298        fr
# 1454  1295602884103776307        fr
#
#                                               Post_Link  Tunisia   Type  \
# 0     http://www.numerama.com/magazine/17884-l-egypt...        2  FORUM
# 1     http://www.numerama.com/magazine/17884-l-egypt...        2  FORUM
# 2     http://forum-photovoltaique.fr/viewtopic.php?t...        2  FORUM
# 3     http://forum.origine-online.com/viewtopic.php?...        5  FORUM
# 4     http://forum.cockos.com/showthread.php?t=73359...        2  FORUM
# 5     http://forum.kokorobox.net/index.php?topic=118...        1  FORUM
# 6     http://forum.kokorobox.net/index.php?topic=118...        2  FORUM
# 7     http://forum.canardpc.com/showthread.php?t=532...        2  FORUM
# 8     http://www.portugal-tchat.com/forum/discussion...        3  FORUM
# 9     http://forums.macgeneration.com/switch-et-cons...        2  FORUM
# 10    http://forum.pvtistes.net/transport/51820-van-...        4  FORUM
# 11    http://forum.pvtistes.net/montreal/51823-demis...        3  FORUM
# 12    http://www.softsclub.com/music/508038-madjo-li...        2  FORUM
# 13    http://www.france-coree.net/viewtopic.php?t=15...        1  FORUM
# 14    http://forums.narutofan.com/showthread.php?t=6...        2  FORUM
# 15    http://forums.narutofan.com/showthread.php?t=6...        2  FORUM
# 16    http://www.babilive.com/forum/elections-et-cri...        2  FORUM
# 17    http://forums.narutofan.com/showthread.php?t=6...        2  FORUM
# 18    http://forum-begaiement.fr/forum/viewtopic.php...        3  FORUM
# 19    http://www.babilive.com/forum/elections-et-cri...        2  FORUM
# 20    http://forum.canardpc.com/showthread.php?t=532...        2  FORUM
# 21    http://jeny.ipro.org/showthread.php?t=5039&got...        2  FORUM
# 22    http://forum.planete-astronomie.com/viewtopic....        2  FORUM
# 23    http://www.france-coree.net/viewtopic.php?t=14...        2  FORUM
# 24    http://www.forum-marketing.com/threads/66741-I...        2  FORUM
# 25    http://forum.pvtistes.net/nouveaux-presentez-v...        2  FORUM
# 26    http://forums.macgeneration.com/switch-et-cons...        2  FORUM
# 27    http://forums.macgeneration.com/switch-et-cons...        2  FORUM
# 28    http://www.cameravideo.net/forum/haute-definit...        5  FORUM
# 29    http://forum.ticklingfr.com/viewtopic.php?t=63...        4  FORUM
# ...                                                 ...      ...    ...
# 1425  http://forum.canardpc.com/showthread.php?t=531...        4  FORUM
# 1426  http://forum.canardpc.com/showthread.php?t=531...        3  FORUM
# 1427  http://www.forumdz.com/showthread.php?30583-La...        2  FORUM
# 1428  http://www.swishtalk.com/showthread.php?t=5108...        2  FORUM
# 1429  http://forum.maxwellrender.fr//viewtopic.php?f...        2  FORUM
# 1430       http://www.game-focus.com/?nav=new&nid=16533        2  FORUM
# 1431  http://www.foudeconcours.com/forum/concours-be...        2  FORUM
# 1432  http://forum.pvtistes.net/toronto/51596-dossie...        4  FORUM
# 1433  http://www.cinetson.org/phpBB3/viewtopic.php?f...        3  FORUM
# 1434  http://forums.munich-french-connection.net/vie...        3  FORUM
# 1435  http://forum.canardpc.com/showthread.php?t=531...        3  FORUM
# 1436  http://forums.archlinux.fr/viewtopic.php?t=738...        2  FORUM
# 1437  http://www.all-musculation.com/forum/index.php...        2  FORUM
# 1438  http://forum.univers-virtuels.net/index.php?sh...        3  FORUM
# 1439  http://www.france-coree.net/viewtopic.php?t=15...        4  FORUM
# 1440  http://www.france-coree.net/viewtopic.php?t=15...        2  FORUM
# 1441  http://www.babilive.com/forum/elections-et-cri...        2  FORUM
# 1442  http://www.businessmeet.com/pg/blog/read/5632/...        2  FORUM
# 1443  http://www.businessmeet.com/pg/blog/read/5630/...        3  FORUM
# 1444  http://www.businessmeet.com/pg/blog/read/5631/...        3  FORUM
# 1445  http://www.businessmeet.com/pg/blog/read/5633/...        4  FORUM
# 1446  http://www.wladbladi.com/forum/documentaires/1...        1  FORUM
# 1447  http://www.liberaux.org/index.php?showtopic=47074        2  FORUM
# 1448  http://www.releasehour.com/forums/ebooks-tutor...        3  FORUM
# 1449  http://forum.ticklingfr.com/viewtopic.php?t=65...        3  FORUM
# 1450  http://forum.ticklingfr.com/viewtopic.php?t=65...        2  FORUM
# 1451  http://forum.ticklingfr.com/viewtopic.php?t=64...        2  FORUM
# 1452  http://forum.ticklingfr.com/viewtopic.php?t=63...        2  FORUM
# 1453  http://forum.ticklingfr.com/viewtopic.php?t=63...        2  FORUM
# 1454  http://forum.ticklingfr.com/viewtopic.php?t=65...        1  FORUM
#
#              Day                                             Tokens         0  \
# 0     2011-01-25  [egypte, tour, internet, egyptiens, rassemblés...  0.052663
# 1     2011-01-25  [egypte, tour, internet, egyptiens, rassemblés...  0.052662
# 2     2011-01-25  [pistes, réflexions, kit, solaire, factures, a...  0.792595
# 3     2011-01-25  [actualités, patch, beta, news, bon, traductio...  0.022456
# 4     2011-01-25  [reaper, instable, besoin, lumières, reaper, s...  0.047081
# 5     2011-01-25  [acheter, indication, hudson, tags, allergie, ...  0.044250
# 6     2011-01-25  [achat, ligne, villeurbanne, tags, cote, utili...  0.053541
# 7     2011-01-25  [préparation, envie, soudaine, tranquillité, p...  0.026787
# 8     2011-01-25  [femme, vie, travaille, forum, personnes, symp...  0.048253
# 9     2011-01-25  [réparation, nouveau, modèle, utilisateur, mod...  0.040464
# 10    2011-01-24  [van, nissan, homy, fabuleux, voyage, fin, dur...  0.031828
# 11    2011-01-25  [démission, préavis, cas, mission, intérim, co...  0.056638
# 12    2011-01-25  [live, semaine, just, madjo, just, release, in...  0.028541
# 13    2011-01-25  [corée, beauté, prix, bref, espère, phénomène,...  0.037958
# 14    2011-01-25  [cialis_paris, salut, tres, bonne, com, excell...  0.824693
# 15    2011-01-25  [cialis_paris, salut, tres, bonne, com, excell...  0.824705
# 16    2011-01-25  [etat, major, armées, doué, dernières, sorties...  0.061938
# 17    2011-01-25  [cialis_paris, salut, tres, bonne, com, excell...  0.824698
# 18    2011-01-25  [ortho, maman, enfant, bonjour, mag, itinérair...  0.027631
# 19    2011-01-25  [morts, manifestations, egypte, caire, reuters...  0.062654
# 20    2011-01-25  [préparation, envie, soudaine, tranquillité, p...  0.026788
# 21    2011-01-25  [comparateur, prix, machine, pain, hydrophobe,...  0.061362
# 22    2011-01-25  [inclassables_astronomie, impossible, sujet, p...  0.030184
# 23    2011-01-25  [reportage, france, travail, notion, sensible,...  0.032339
# 24    2011-01-25  [internet, court, adresses, glenn, chapman, qu...  0.035526
# 25    2011-01-25  [présentation, nouvelle, hello, everybody, ade...  0.044546
# 26    2011-01-25  [réparation, nouveau, modèle, utilisateur, mod...  0.040491
# 27    2011-01-25  [réparation, nouveau, modèle, utilisateur, mod...  0.040505
# 28    2011-01-25  [sony, présentation, sympathique, dénuée, inté...  0.025526
# 29    2011-01-25  [tome, ténèbres, chapitre, cataclysme, semaine...  0.023482
# ...          ...                                                ...       ...
# 1425  2011-01-21  [allemagne, bataille, histoire, mec, connaisse...  0.026276
# 1426  2011-01-21  [petit, monumental, types, studios, affaires, ...  0.028781
# 1427  2011-01-21  [nintendo, 3ds, lunettes, européenne, mars, ma...  0.030841
# 1428  2011-01-21  [saturne, immatériel, pantouflions, meilleur, ...  0.049188
# 1429  2011-01-21  [auteur, forum, date, sebastien, 24ans, concep...  0.044794
# 1430  2011-01-21  [journal, techno, semaine, planet, émission, j...  0.579927
# 1431  2011-01-20  [voili_voilou, the, suite, tit, belgique, mère...  0.052556
# 1432  2011-01-20  [dossier, toronto, toronto, dossier, toronto, ...  0.021249
# 1433  2011-01-21  [mitsubishi, diamond, full, petits, exemples, ...  0.033199
# 1434  2011-01-21  [résa, festival, opéra, demain, ven, jan, rése...  0.046401
# 1435  2011-01-21  [petit, monumental, types, studios, affaires, ...  0.028781
# 1436  2011-01-21  [installation, configuration, table, partition...  0.040339
# 1437  2011-01-21  [cahier, forum, site, all, musculation, recher...  0.030600
# 1438  2011-01-21  [forsaken, world, premier, chapitre, grand, mo...  0.033702
# 1439  2011-01-21  [économie, croissance, pourquoi, économie, cro...  0.030141
# 1440  2011-01-21  [corée, beauté, prix, penser, société, personn...  0.045237
# 1441  2011-01-21  [crise, électorale, armée, véhicules, inter, f...  0.084492
# 1442  2011-01-21  [chaussures_nike, droit, avion, président, amé...  0.037767
# 1443  2011-01-21  [magasin, magasin, idées, intelligentes, look,...  0.031079
# 1444  2011-01-21  [chaussures, chaussures, 18chaussures, classic...  0.868714
# 1445  2011-01-21  [chaussures, chaussures, styles, vêtements, go...  0.026737
# 1446  2011-01-21  [cabale, manipulations, capitalisme, guerre, c...  0.789559
# 1447  2011-01-21  [universités, européennes, crise, normal, fran...  0.039078
# 1448  2011-01-21  [canard, pdf, french, hebdomadaire, satirique,...  0.754262
# 1449  2011-01-21  [histoires, prix, avantage, instant, présent, ...  0.027264
# 1450  2011-01-19  [chroniques, univers, ennemi, poignard, face, ...  0.028111
# 1451  2011-01-19  [mésaventures, hein, poche, partie, télé, tabl...  0.022167
# 1452  2011-01-17  [histoires_fictives, fleuve, sens, croatie, lo...  0.847796
# 1453  2011-01-17  [histoires_fictives, bon, mélange, tre, vote, ...  0.027306
# 1454  2011-01-15  [histoires, prix, nouvelle, fois, concertation...  0.031094
#
#              1         2         3         4         5
# 0     0.052876  0.052528  0.052561  0.052716  0.736656
# 1     0.052849  0.052527  0.052561  0.052715  0.736685
# 2     0.041458  0.041488  0.041469  0.041624  0.041367
# 3     0.022460  0.022422  0.885433  0.024813  0.022416
# 4     0.046956  0.047151  0.046984  0.764913  0.046915
# 5     0.044166  0.779423  0.044086  0.044116  0.043958
# 6     0.053248  0.053342  0.733495  0.053244  0.053131
# 7     0.866111  0.026794  0.026781  0.026752  0.026774
# 8     0.047987  0.048035  0.048082  0.048114  0.759528
# 9     0.040034  0.040238  0.798938  0.040039  0.040287
# 10    0.031974  0.031769  0.031718  0.840867  0.031843
# 11    0.056411  0.716513  0.056846  0.056743  0.056850
# 12    0.857628  0.028485  0.028437  0.028500  0.028408
# 13    0.285297  0.037884  0.037907  0.562995  0.037959
# 14    0.035132  0.035092  0.034978  0.035025  0.035080
# 15    0.035111  0.035100  0.034978  0.035027  0.035080
# 16    0.061669  0.061740  0.061820  0.690851  0.061983
# 17    0.035127  0.035092  0.034978  0.035026  0.035080
# 18    0.027498  0.027506  0.027374  0.862483  0.027507
# 19    0.686046  0.062700  0.062764  0.063188  0.062648
# 20    0.866102  0.026790  0.026793  0.026752  0.026775
# 21    0.061385  0.061539  0.692993  0.061364  0.061357
# 22    0.849302  0.030119  0.030247  0.030079  0.030069
# 23    0.838415  0.032303  0.032267  0.032417  0.032259
# 24    0.822315  0.035568  0.035497  0.035624  0.035470
# 25    0.044553  0.044525  0.044388  0.777656  0.044333
# 26    0.040034  0.040238  0.798911  0.040039  0.040287
# 27    0.040034  0.040240  0.798889  0.040040  0.040293
# 28    0.872214  0.025570  0.025550  0.025608  0.025531
# 29    0.882527  0.023553  0.023401  0.023464  0.023572
# ...        ...       ...       ...       ...       ...
# 1425  0.026375  0.026250  0.026251  0.868479  0.026369
# 1426  0.028818  0.028794  0.856053  0.028773  0.028780
# 1427  0.030720  0.030658  0.030572  0.846509  0.030699
# 1428  0.049482  0.049035  0.754168  0.049136  0.048992
# 1429  0.044896  0.044799  0.775761  0.044914  0.044836
# 1430  0.083999  0.084174  0.083709  0.083836  0.084355
# 1431  0.052363  0.052469  0.052446  0.052704  0.737462
# 1432  0.021288  0.021220  0.021236  0.893782  0.021226
# 1433  0.033331  0.033222  0.033303  0.833610  0.033335
# 1434  0.046533  0.046550  0.046699  0.767295  0.046521
# 1435  0.028830  0.028794  0.856041  0.028773  0.028780
# 1436  0.040461  0.797563  0.040731  0.040525  0.040381
# 1437  0.030512  0.030497  0.030486  0.847428  0.030477
# 1438  0.033784  0.033710  0.831160  0.033933  0.033712
# 1439  0.030185  0.030255  0.030065  0.030210  0.849145
# 1440  0.045186  0.045136  0.045200  0.773865  0.045375
# 1441  0.580117  0.083798  0.083647  0.084525  0.083422
# 1442  0.498430  0.350681  0.037728  0.037641  0.037751
# 1443  0.844592  0.031045  0.031089  0.031063  0.031132
# 1444  0.026257  0.026204  0.026323  0.026290  0.026213
# 1445  0.026765  0.026808  0.026759  0.866157  0.026775
# 1446  0.042088  0.042108  0.042077  0.042068  0.042100
# 1447  0.039083  0.038961  0.039008  0.804687  0.039183
# 1448  0.049058  0.049025  0.049187  0.049137  0.049331
# 1449  0.863967  0.027211  0.027138  0.027171  0.027249
# 1450  0.859545  0.028093  0.028138  0.028081  0.028033
# 1451  0.889177  0.022180  0.022164  0.022165  0.022147
# 1452  0.030468  0.030437  0.030365  0.030463  0.030472
# 1453  0.027331  0.863406  0.027228  0.027344  0.027385
# 1454  0.031296  0.031044  0.030978  0.031089  0.844500
#
# [1455 rows x 16 columns]

# %%
def plot_topic_time_distribution(df, max_, country, n_topics, filename, column_names):
    """
    Plotting the time series for a given dataframe.
    :param df: DataFrame
    :param max_: int
    :param country: string
    """
    title = 'Distribution of topics over time in {}'.format(country)
    topics = dict((index, column_names[index]) for index in range(n_topics))
    df.rename(columns=topics, inplace=True)
    df.groupby(['Day'])[column_names].mean().plot.area(figsize=(15,9.6), lw=0, 
                                                       title=title, colormap='Accent', 
                                                       alpha= 0.4, ylim=(0,1));
    plt.ylabel('Proportion of Topics per day')
    plt.legend(loc='lower right');
    plt.xticks(np.arange(len(df.Day.unique())), [
        day.replace('2011-01','Jan').replace('2011-02', 'Feb') for day in sorted(df.Day.unique())], rotation = 90)
    line_details = {1: ['k', 'Tunisian President Resigns'],
                    4: ['k', 'New Tunisian Cabinet Announced'],
                    12: ['k', 'Egyptian Revolution Begins'],
                    15: ['k', 'Day of Rage in Egypt'],
                    29: ['k', 'Egyptian President Resigns']}
    for index in line_details:
        plt.axvline(index, color=line_details[index][0], lw=1);
        plt.text(index + 0.1, max_, line_details[index][1],rotation=90, verticalalignment='top');
    
    plt.savefig(filename, format='jpg', dpi=80)

# %% [markdown]
# ## Egypt EN Social Media

# %%
showcase_df = showcase_topic_modelling(EG, 'SOCIAL_MEDIA', EN, n_topics=3, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 89015

# %%
plot_topic_time_distribution(showcase_df, 1, EG,  n_topics=3,  filename='Topic_Distribution/EG_SOCIAL_MEDIA_en.jpg',
                             column_names=['United States Intervention', "Domino Effect", 'Egyptian Protests'])

# %% [markdown]
# ## Egypt EN WEBLOG

# %%
showcase_df = showcase_topic_modelling(EG, 'WEBLOG', EN, n_topics=4, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 119078

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=4, filename='Topic_Distribution/EG_WEBLOG_en.jpg',
                            column_names=['International Reactions', 'Protests', 'Arab Nation', 'Internet Activism' ])

# %% [markdown]
# ## Egypt EN NEWS

# %%
showcase_df = showcase_topic_modelling(EG, 'MAINSTREAM_NEWS', EN, n_topics=4, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 132225

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=4, filename='Topic_Distribution/EG_NEWS_en.jpg',
                             column_names = ['International Reactions', "President Resignation",
                                             'Protests', 'Predicting Revolution'])

# %% [markdown]
# ## Egypt EN FORUM

# %%
showcase_df = showcase_topic_modelling(EG, 'FORUM', EN, n_topics=3, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 31200

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=3,  filename='Topic_Distribution/EG_FORUM_en.jpg', 
                             column_names = ['United States Intervention','Popular Concerns','Noise'])

# %% [markdown]
# ## Tunisia EN SOCIAL MEDIA

# %%
showcase_df = showcase_topic_modelling(TN, 'SOCIAL_MEDIA', EN, n_topics=4, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 34839

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=4, filename = 'Topic_Distribution/TN_SOCIAL_MEDIA_en.jpg',
                            column_names = ['Noise_1','International Reactions','Noise_2', 'Domino Effect'])

# %% [markdown]
# ## Tunisian EN WEBLOG

# %%
showcase_df = showcase_topic_modelling(TN, 'WEBLOG', EN, n_topics=4, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 41559

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=4, filename='Topic_Distribution/EN_WEBLOG_en.jpg', 
                            column_names = ['International Reactions','Block Effect', 'Pos Revolution', 'Malaysia’s Contamination'])

# %% [markdown]
# ## Tunisian EN NEWS

# %%
showcase_df = showcase_topic_modelling(TN, 'MAINSTREAM_NEWS', EN, n_topics=4, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 56907

# %%
plot_topic_time_distribution(showcase_df, 1, EG,n_topics=4, filename = 'Topic_Distribution/TN_NEWS_en.jpg',
                            column_names = ['Concerns', 'Protests','Noise', 'Haiti natural catastrophes'])

# %% [markdown]
# ## Tunisian EN FORUM

# %%
showcase_df = showcase_topic_modelling(TN, 'FORUM', EN, n_topics=3, LSA=False, no_above=0.5, no_below=10)
# Out:
# +++++++++++++++++++
# The LDA model:
# +++++++++++++++++++
#
# Number of posts: 22090

# %%
plot_topic_time_distribution(showcase_df, 1, EG, n_topics=3, filename = 'Topic_Distribution/TN_FORUM_en.jpg',
                            column_names = ['Noise',  'International Reactions','Protests'])

# %% [markdown]
# # 6. Conclusion<a class="anchor" id="6"></a>
#
# U hv to come to d labs xoxo
