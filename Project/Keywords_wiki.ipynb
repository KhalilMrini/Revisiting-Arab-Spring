# %% [markdown]
# # Imports

# %%
import wikipedia
from collections import Counter
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import regexp_tokenize
from nltk.collocations import BigramCollocationFinder
import string
import numpy as np
import operator

# %% [markdown]
# ### Scrap wiki page and get keywords

# %%
def get_KeyWords(wiki_page, num_keywords, language, s_lang):
    #download wikipedia page
    wikipedia.set_lang(language)
    wiki = wikipedia.page(wiki_page)

    #initialize token's counter
    tknzr = WordPunctTokenizer()
    wiki_tokens = tknzr.tokenize(wiki.content)
    count = Counter(wiki_tokens)  
    
    #remove stop words
    count_filtered = {k.lower():v for k,v in count.items() if k.lower() not in stopwords.words(s_lang) 
                      and k not in string.punctuation}
    sorted_count = sorted(count_filtered.items(), key=operator.itemgetter(1), reverse=True)
    
    return [i[0] for i in sorted_count][:num_keywords]

# %%
get_KeyWords('Tunisian Revolution', 50, "en", 'english')
# Out:
# ['tunisia',
#  'ben',
#  'ali',
#  'tunisian',
#  'government',
#  '."',
#  '==',
#  'january',
#  'said',
#  'would',
#  'arab',
#  'february',
#  'country',
#  'security',
#  'tunis',
#  'rcd',
#  'new',
#  '2011',
#  'december',
#  'minister',
#  'ghannouchi',
#  'bouazizi',
#  'president',
#  'world',
#  'later',
#  'revolution',
#  'mohamed',
#  'called',
#  'sidi',
#  'bouzid',
#  '000',
#  'one',
#  'mebazaa',
#  'interim',
#  '===',
#  'forces',
#  '2010',
#  'power',
#  'national',
#  'foreign',
#  'members',
#  'demonstrations',
#  'region',
#  'arrested',
#  'across',
#  'announced',
#  'emergency',
#  'saying',
#  'including',
#  'zine']

# %%
get_KeyWords('Révolution tunisienne', 50, 'fr', 'french')
# Out:
# ['les',
#  '«',
#  'ben',
#  '’',
#  'ali',
#  'janvier',
#  '===',
#  '»',
#  'tunisie',
#  '2011',
#  '====',
#  '—',
#  'a',
#  'annonce',
#  'ancien',
#  'manifestants',
#  'régime',
#  'morts',
#  '».',
#  'police',
#  'tunis',
#  'tunisienne',
#  '»,',
#  'mohamed',
#  'pays',
#  'dont',
#  'blessés',
#  'contre',
#  'tunisien',
#  'ainsi',
#  'fait',
#  'sidi',
#  'bouzid',
#  'rcd',
#  'ghannouchi',
#  '==',
#  'ugtt',
#  'jour',
#  'comme',
#  'décembre',
#  'départ',
#  '17',
#  '14',
#  'février',
#  'place',
#  'état',
#  '2010',
#  'personnes',
#  'jours',
#  'ordre']

# %%
get_KeyWords('الثورة التونسية', 50, 'ar', 'arabic')
# Out:
# ['،',
#  'تونس',
#  'الثورة',
#  'بن',
#  'علي',
#  'التونسي',
#  'التونسية',
#  'ً',
#  '2011',
#  'ا',
#  'الرئيس',
#  'الأمن',
#  'يناير',
#  'محمد',
#  'يوم',
#  'كانون',
#  'الاحتجاجات',
#  'العربية',
#  'العاصمة',
#  'الشعب',
#  'ديسمبر',
#  'جانفي',
#  '2010',
#  'قوات',
#  'الأول',
#  'العابدين',
#  'عدد',
#  'عبد',
#  'وقد',
#  'سيدي',
#  'زين',
#  'السعودية',
#  'الثاني',
#  'المظاهرات',
#  'النظام',
#  'بوزيد',
#  'وذلك',
#  'ضد',
#  'وفي',
#  '17',
#  'البوعزيزي',
#  'مدن',
#  'خلال',
#  'الحكومة',
#  'عربية',
#  '14',
#  'أعلن',
#  'الأوضاع',
#  'القذافي',
#  'الجيش']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.metrics import BigramAssocMeasures

def get_bigrams(myString):
    tokenizer = WordPunctTokenizer()
    tokens = tokenizer.tokenize(myString)
    wordnet_lemmatizer = WordNetLemmatizer()
    bigram_finder = BigramCollocationFinder.from_words(tokens)
    bigrams = bigram_finder.nbest(BigramAssocMeasures.chi_sq, 500)

    for bigram_tuple in bigrams:
        x = "%s %s" % bigram_tuple
        tokens.append(x)

    result = [' '.join([wordnet_lemmatizer.lemmatize(w).lower() for w in x.split()]) for x in tokens if x.lower() not in stopwords.words('english') and len(x) > 8]
    return result

# %%
words = ['amazing', 'interesting', 'love', 'great', 'nice', 'really']

for w in words:
    tmp = wn.synsets(w)[0].pos()
    print( w, ":", tmp)
# Out:
# amazing : v
# interesting : v
# love : n
# great : n
# nice : n
# really : r

# %%
tr = wikipedia.page('Tunisian Revolution').content
frq_words = get_bigrams(tr)

# %%
Counter(frq_words).most_common()
# Out:
# [('government', 40),
#  ('protester', 23),
#  ('revolution', 21),
#  ('president', 20),
#  ('ghannouchi', 16),
#  ('following', 14),
#  ('international', 14),
#  ('political', 13),
#  ('demonstration', 9),
#  ('democratic', 8),
#  ('announced', 8),
#  ('emergency', 8),
#  ('including', 7),
#  ('election', 7),
#  ('announces', 7),
#  ('minister', 7),
#  ('country', 6),
#  ('solidarity', 6),
#  ('authority', 6),
#  ('continued', 6),
#  ('criticised', 6),
#  ('demonstrator', 5),
#  ('democracy', 5),
#  ('constitutional', 5),
#  ('repression', 5),
#  ('constitution', 5),
#  ('corruption', 4),
#  ('immolation', 4),
#  ('supported', 4),
#  ('activist', 4),
#  ('headquarters', 4),
#  ('islamists', 4),
#  ('suggested', 4),
#  ('unemployment', 3),
#  ('officially', 3),
#  ('opposition', 3),
#  ('marginalisation', 3),
#  ('confiscated', 3),
#  ('official', 3),
#  ('responded', 3),
#  ('operation', 3),
#  ('criticism', 3),
#  ('television', 3),
#  ('communication', 3),
#  ('governor', 3),
#  ('communist', 3),
#  ('stability', 3),
#  ('population', 3),
#  ('presidential', 3),
#  ('struggling', 3),
#  ('thousands', 3),
#  ('protestors', 3),
#  ('legalised', 3),
#  ('protesters', 3),
#  ('resignation', 3),
#  ('constituent', 3),
#  ('immigration', 3),
#  ('eventually', 2),
#  ('condition', 2),
#  ('throughout', 2),
#  ('journalist', 2),
#  ('development', 2),
#  ('criticized', 2),
#  ('generally', 2),
#  ('previously', 2),
#  ('controlled', 2),
#  ('policewoman', 2),
#  ('wikileaks', 2),
#  ('document', 2),
#  ('contributed', 2),
#  ('demonstrate', 2),
#  ('treatment', 2),
#  ('financial', 2),
#  ('increased', 2),
#  ('resident', 2),
#  ('independent', 2),
#  ('gathering', 2),
#  ('censorship', 2),
#  ('broadcast', 2),
#  ('allegedly', 2),
#  ('password', 2),
#  ('building', 2),
#  ('personnel', 2),
#  ('broadcaster', 2),
#  ('organised', 2),
#  ('prisoner', 2),
#  ('perpetrator', 2),
#  ('punishment', 2),
#  ('religious', 2),
#  ('described', 2),
#  ('terrorist', 2),
#  ('progressive', 2),
#  ('procession', 2),
#  ('reporters', 2),
#  ('attention', 2),
#  ('appointed', 2),
#  ('prominent', 2),
#  ('dissolved', 2),
#  ('tunisians', 2),
#  ('protection', 2),
#  ('departure', 2),
#  ('presidency', 2),
#  ('parliamentary', 2),
#  ('confirmed', 2),
#  ('commentator', 2),
#  ('representative', 2),
#  ('resigning', 2),
#  ('cooperation', 2),
#  ('distribution', 2),
#  ('relations', 2),
#  ('successor', 2),
#  ('suspended', 2),
#  ('dissolution', 2),
#  ('parliament', 2),
#  ('convention', 2),
#  ('associated', 2),
#  ('responsibility', 2),
#  ('voluntary', 2),
#  ('patrolling', 2),
#  ('organisation', 2),
#  ('expressed', 2),
#  ('mainstream', 2),
#  ('technology', 2),
#  ('autocratic', 2),
#  ('ultimately', 2),
#  ('situation', 2),
#  ('spillover', 2),
#  ('resonated', 2),
#  ('deteriorated', 2),
#  ('conflict', 2),
#  ('collected', 2),
#  ('commentary', 2),
#  ('constituent assembly', 2),
#  ('intensive', 1),
#  ('resistance', 1),
#  ('democratization', 1),
#  ('inflation', 1),
#  ('constituted', 1),
#  ('contribution', 1),
#  ('pluralistic', 1),
#  ('geopolitical', 1),
#  ('nomenclature', 1),
#  ('originated', 1),
#  ('surrounding', 1),
#  ('influence', 1),
#  ('intellectual', 1),
#  ('translation', 1),
#  ('background', 1),
#  ('characterized', 1),
#  ('investment', 1),
#  ('reaction', 1),
#  ('instance', 1),
#  ('headline', 1),
#  ('noteworthy', 1),
#  ('especially', 1),
#  ('considered', 1),
#  ('successfully', 1),
#  ('repressed', 1),
#  ('unemployed', 1),
#  ('outspoken', 1),
#  ('employment', 1),
#  ('traditionally', 1),
#  ('subsidized', 1),
#  ('providence', 1),
#  ('bidonvilles', 1),
#  ('combination', 1),
#  ('characteristic', 1),
#  ('society', 1),
#  ('vegetable', 1),
#  ('equivalent', 1),
#  ('confiscating', 1),
#  ('humiliated', 1),
#  ('provincial', 1),
#  ('municipality', 1),
#  ('confrontation', 1),
#  ('flammable', 1),
#  ('subsequent', 1),
#  ('unnoticed', 1),
#  ('dispersing', 1),
#  ('subsequently', 1),
#  ('transferred', 1),
#  ('newspaper', 1),
#  ('simultaneously', 1),
#  ('published', 1),
#  ('confidential', 1),
#  ('description', 1),
#  ('information', 1),
#  ('obstructing', 1),
#  ('joblessness', 1),
#  ('electrocuting', 1),
#  ('electricity', 1),
#  ('difficulty', 1),
#  ('programme', 1),
#  ('belhoussine', 1),
#  ('governorate', 1),
#  ('encountered', 1),
#  ('expressing', 1),
#  ('federation', 1),
#  ('peacefully', 1),
#  ('unconfirmed', 1),
#  ('attempting', 1),
#  ('according', 1),
#  ('association', 1),
#  ('unjustified', 1),
#  ('ransacking', 1),
#  ('ettadhamen', 1),
#  ('cameraman', 1),
#  ('establishing', 1),
#  ('caliphate', 1),
#  ('photojournalist', 1),
#  ('pressphoto', 1),
#  ('extremist', 1),
#  ('mercenary', 1),
#  ('broadcasting', 1),
#  ('allegation', 1),
#  ('verification', 1),
#  ('dramatization', 1),
#  ('fermentation', 1),
#  ('deformation', 1),
#  ('announcing', 1),
#  ('handicraft', 1),
#  ('portfolio', 1),
#  ('dismissal', 1),
#  ('civilian', 1),
#  ('overlooked', 1),
#  ('scapegoat', 1),
#  ('additional', 1),
#  ('webloggers', 1),
#  ('disappeared', 1),
#  ('secretary', 1),
#  ('indefinite', 1),
#  ('university', 1),
#  ('departing', 1),
#  ('promising', 1),
#  ('officials', 1),
#  ('declaration', 1),
#  ('otherwise', 1),
#  ('territory', 1),
#  ('exceptional', 1),
#  ('circumstance', 1),
#  ('accepting', 1),
#  ('overthrow', 1),
#  ('commander', 1),
#  ('returning', 1),
#  ('abdennadher', 1),
#  ('relative', 1),
#  ('commission', 1),
#  ('supervision', 1),
#  ('extensively', 1),
#  ('determined', 1),
#  ('rebellion', 1),
#  ('suspected', 1),
#  ('residents', 1),
#  ('necessary', 1),
#  ('barricaded', 1),
#  ('neighbourhood', 1),
#  ('correspondent', 1),
#  ('apparently', 1),
#  ('different', 1),
#  ('supposedly', 1),
#  ('irregular', 1),
#  ('supportive', 1),
#  ('threatening', 1),
#  ('fomenting', 1),
#  ('reportedly', 1),
#  ('struggled', 1),
#  ('immediate', 1),
#  ('accessible', 1),
#  ('dailymotion', 1),
#  ('available', 1),
#  ('anonymity', 1),
#  ('liberties', 1),
#  ('movement', 1),
#  ('reformist', 1),
#  ('relatively', 1),
#  ('participation', 1),
#  ('demonstrating', 1),
#  ('confidence', 1),
#  ('membership', 1),
#  ('inclusion', 1),
#  ('disbanded', 1),
#  ('confidant', 1),
#  ('architect', 1),
#  ('committee', 1),
#  ('participate', 1),
#  ('transparent', 1),
#  ('attributed', 1),
#  ('reverberation', 1),
#  ('reshuffle', 1),
#  ('reorganised', 1),
#  ('economist', 1),
#  ('administrative', 1),
#  ('protesting', 1),
#  ('remaining', 1),
#  ('coordinating', 1),
#  ('saifeddine', 1),
#  ('missraoui', 1),
#  ('protestor', 1),
#  ('insisting', 1),
#  ('concurrently', 1),
#  ('accusation', 1),
#  ('destabilize', 1),
#  ('infrastructure', 1),
#  ('ghazouani', 1),
#  ('firebomb', 1),
#  ('immediately', 1),
#  ('controversial', 1),
#  ('activity', 1),
#  ('breakdown', 1),
#  ('completed', 1),
#  ('mandatory', 1),
#  ('dominated', 1),
#  ('agreement', 1),
#  ('nomination', 1),
#  ('disappearance', 1),
#  ('degrading', 1),
#  ('abolishing', 1),
#  ('demanding', 1),
#  ('completely', 1),
#  ('convinced', 1),
#  ('conviction', 1),
#  ('shouldering', 1),
#  ('decision', 1),
#  ('casualty', 1),
#  ('continuing', 1),
#  ('education', 1),
#  ('scientific', 1),
#  ('postponed', 1),
#  ('fulfilled', 1),
#  ('hallmark', 1),
#  ('liquidation', 1),
#  ('manslaughter', 1),
#  ('trafficking', 1),
#  ('rewriting', 1),
#  ('capturing', 1),
#  ('reactions', 1),
#  ('extradite', 1),
#  ('regarding', 1),
#  ('involvement', 1),
#  ('perpetrating', 1),
#  ('lampedusa', 1),
#  ('collapsing', 1),
#  ('permission', 1),
#  ('intervene', 1),
#  ('suggesting', 1),
#  ('categorically', 1),
#  ('interference', 1),
#  ('infringement', 1),
#  ('sovereignty', 1),
#  ('logistical', 1),
#  ('equipment', 1),
#  ('establish', 1),
#  ('technique', 1),
#  ('checkpoint', 1),
#  ('quarantined', 1),
#  ('humanitarian', 1),
#  ('migration', 1),
#  ('catherine', 1),
#  ('chancellor', 1),
#  ('strengthen', 1),
#  ('consecutive', 1),
#  ('protecting', 1),
#  ('sovereign', 1),
#  ('ghanoucchi', 1),
#  ('supranational', 1),
#  ('socialist', 1),
#  ('resultant', 1),
#  ('philosopher', 1),
#  ('inappropriate', 1),
#  ('accompanied', 1),
#  ('initially', 1),
#  ('widespread', 1),
#  ('particularly', 1),
#  ('providing', 1),
#  ('sympathetic', 1),
#  ('intervened', 1),
#  ('approving', 1),
#  ('circumvention', 1),
#  ('overture', 1),
#  ('momentous', 1),
#  ('similarity', 1),
#  ('ceauşescu', 1),
#  ('governing', 1),
#  ('nevertheless', 1),
#  ('management', 1),
#  ('protectorate', 1),
#  ('maintained', 1),
#  ('relation', 1),
#  ('repercussion', 1),
#  ('shattered', 1),
#  ('disintegrating', 1),
#  ('statement', 1),
#  ('entourage', 1),
#  ('christian', 1),
#  ('telecommunication', 1),
#  ('influential', 1),
#  ('speculation', 1),
#  ('birthplace', 1),
#  ('communism', 1),
#  ('editorial', 1),
#  ('columnist', 1),
#  ('conventional', 1),
#  ('monopolised', 1),
#  ('incarnation', 1),
#  ('apparatus', 1),
#  ('uncertainty', 1),
#  ('eastward', 1),
#  ('marginalised', 1),
#  ('fatalistic', 1),
#  ('restoring', 1),
#  ('succeeded', 1),
#  ('leadership', 1),
#  ('ostensible', 1),
#  ('contained', 1),
#  ('desperately', 1),
#  ('crossroad', 1),
#  ('successful', 1),
#  ('unprecedented', 1),
#  ('collapsed', 1),
#  ('similarly', 1),
#  ('inspiring', 1),
#  ('sclerotic', 1),
#  ('supporting', 1),
#  ('commencing', 1),
#  ('capitalist', 1),
#  ('globalisation', 1),
#  ('nationalism', 1),
#  ('administration', 1),
#  ('standard', 1),
#  ('extremism', 1),
#  ('afghanistan', 1),
#  ('foundation', 1),
#  ('accelerating', 1),
#  ('scenario', 1),
#  ('dictator', 1),
#  ('civilised', 1),
#  ('demographic', 1),
#  ('explosion', 1),
#  ('suspending', 1),
#  ('initiating', 1),
#  ('destination', 1),
#  ('hounshell', 1),
#  ('precedent', 1),
#  ('something', 1),
#  ('horrifying', 1),
#  ('desperate', 1),
#  ('instantly', 1),
#  ('revulsion', 1),
#  ('particular', 1),
#  ('contributor', 1),
#  ('mobilisation', 1),
#  ('intricate', 1),
#  ('important', 1),
#  ('reporting', 1),
#  ('instability', 1),
#  ('parallel', 1),
#  ('beginning', 1),
#  ('kazakhstan', 1),
#  ('resulting', 1),
#  ('experienced', 1),
#  ('turbulence', 1),
#  ('aftermath', 1),
#  ('congress', 1),
#  ('supporter', 1),
#  ('references', 1),
#  ('alexander', 1),
#  ('christopher', 1),
#  ('routledge', 1),
#  ('rivoluzione', 1),
#  ('transitional', 1),
#  ('/ activist', 1),
#  ('190 mile', 1),
#  ('2002 constitutional', 1),
#  ('287 leaked', 1),
#  ('afif chelbi', 1),
#  ('afrique presse', 1),
#  ('andy carvin', 1),
#  ('angela merkel', 1),
#  ('another protestor', 1),
#  ('army commander', 1),
#  ('article 57', 1),
#  ('azyz amamy', 1),
#  ('bastille day', 1),
#  ('belhaj kacem', 1),
#  ('blake hounshell', 1),
#  ('brian whitaker', 1),
#  ('business anti', 1),
#  ('béji caïd', 1),
#  ('catherine ashton', 1),
#  ('central bureau', 1),
#  ('chancellor angela', 1),
#  ('chawki belhoussine', 1),
#  ('christian science', 1),
#  ('commander rashid', 1),
#  ('degrading treatment', 1),
#  ('der spiegel', 1),
#  ('dialogue quartet', 1),
#  ('diario di', 1),
#  ('eddine kchouk', 1),
#  ('elliot abrams', 1),
#  ('enforced disappearance', 1),
#  ('external link', 1),
#  ('farhat rajhi', 1),
#  ('fethi abdennadher', 1),
#  ('franco frattini', 1),
#  ('friday prayer', 1),
#  ('further reading', 1),
#  ('german chancellor', 1),
#  ('governorate encountered', 1),
#  ('gulf cooperation', 1),
#  ('gun battle', 1),
#  ('higher education', 1),
#  ('hounshell wrote', 1),
#  ('initial impact', 1),
#  ('khaled ghazouani', 1),
#  ('lahseen naji', 1),
#  ('lamis ardoni', 1),
#  ('larbi sadiki', 1),
#  ('lawyers order', 1),
#  ('local development', 1),
#  ('lucas dolega', 1),
#  ('michele alliot', 1),
#  ('middle east', 1),
#  ('mokhtar trifi', 1),
#  ('mouldi kefi', 1),
#  ('naim garbousi', 1),
#  ('nicolae ceauşescu', 1),
#  ('nicolas sarkozy', 1),
#  ('nobel peace', 1),
#  ('obama administration', 1),
#  ('optional protocol', 1),
#  ('oussama romdhani', 1),
#  ('pakistan area', 1),
#  ('peace prize', 1),
#  ('portal turmoil', 1),
#  ('presidential palace', 1),
#  ('pressphoto agency', 1),
#  ('public outrage', 1),
#  ('rafik belhaj', 1),
#  ('rami khouri', 1),
#  ('regional instability', 1),
#  ('repercussion analysis', 1),
#  ('reports emerged', 1),
#  ('robert fisk', 1),
#  ('roberto maroni', 1),
#  ('roger cohen', 1),
#  ('saifeddine missraoui', 1),
#  ('salafist ansar', 1),
#  ('science monitor', 1),
#  ('scientific research', 1),
#  ('seddik deemed', 1),
#  ('sidi bouzid', 1),
#  ('slah eddine', 1),
#  ('slim amamou', 1),
#  ('steven cook', 1),
#  ('syria experienced', 1),
#  ('tor anonymity', 1),
#  ('transitional justice', 1),
#  ('until now', 1),
#  ('youssef seddik', 1),
#  ('zouhair m', 1),
#  ('absolute grip', 1),
#  ('accelerating curve', 1),
#  ('accept unjustified', 1),
#  ('activist jillian', 1),
#  ('allusion refers', 1),
#  ('always praised', 1),
#  ('annual award', 1),
#  ('approving circumvention', 1),
#  ('bar association', 1),
#  ('biblical exodus', 1),
#  ('bin laden', 1),
#  ('blow eastward', 1),
#  ('broadcasting false', 1),
#  ('business debt', 1),
#  ('camp beside', 1),
#  ('capturing 41', 1),
#  ('career diplomat', 1),
#  ('categorically reject', 1),
#  ('caught unawares', 1),
#  ('circumvention technology', 1),
#  ('civilian inside', 1),
#  ('clarify what', 1),
#  ('class suburb', 1),
#  ('clean hand', 1),
#  ('clear message', 1),
#  ('close confidant', 1),
#  ('collapsing \'"', 1),
#  ('columnist rami', 1),
#  ('controversial praise', 1),
#  ('conventional wisdom', 1),
#  ('coup seems', 1),
#  ('debate surrounding', 1),
#  ('deceased father', 1),
#  ('decisive contribution', 1),
#  ('deflect blame', 1),
#  ('demographic explosion', 1),
#  ('desperate tactic', 1),
#  ('desperately clinging', 1),
#  ('difficulty arising', 1),
#  ('dinar fine', 1),
#  ('double standard', 1),
#  ('dramatic wave', 1),
#  ('draw parallel', 1),
#  ('eastward towards', 1),
#  ('elected constituent', 1),
#  ('electricity pylon', 1),
#  ('ever shattered', 1),
#  ('exceptional circumstance', 1),
#  ('false allegation', 1),
#  ('fatalistic scream', 1),
#  ('federal aid', 1),
#  ('fight osama', 1),
#  ('fishing port', 1),
#  ('flammable liquid', 1),
#  ('found sign', 1),
#  ('friendly relation', 1),
#  ('geopolitical nomenclature', 1),
#  ('glass ceiling', 1),
#  ('governing strategy', 1),
#  ('gravely ill', 1),
#  ('holiday destination', 1),
#  ('income earner', 1),
#  ('indefinite closure', 1),
#  ('influence behind', 1),
#  ('inhuman globalisation', 1),
#  ('instantly attracts', 1),
#  ('intensive campaign', 1),
#  ('intricate effort', 1),
#  ('irregular militia', 1),
#  ('jail break', 1),
#  ('kept silent', 1),
#  ('labeled confidential', 1),
#  ('largely unnoticed', 1),
#  ('leaving here', 1),
#  ('lethal combination', 1),
#  ('likely mean', 1),
#  ('long fought', 1),
#  ('longer immune', 1),
#  ('maintained friendly', 1),
#  ('masked gang', 1),
#  ('mean abolishing', 1),
#  ('medical staff', 1),
#  ('middle attack', 1),
#  ('might win', 1),
#  ('militia supportive', 1),
#  ('mobile telecommunication', 1),
#  ('month ago', 1),
#  ('neighbourhood watch', 1),
#  ('nevertheless regarded', 1),
#  ('otherwise courting', 1),
#  ('overture toward', 1),
#  ('peaceful marcher', 1),
#  ('philosopher youssef', 1),
#  ('phishing operation', 1),
#  ('piu paura', 1),
#  ('poetic influence', 1),
#  ('precedent raised', 1),
#  ('prisoner release', 1),
#  ('real vision', 1),
#  ('reduced illegal', 1),
#  ('reformist congress', 1),
#  ('remained accessible', 1),
#  ('replaces 34', 1),
#  ('rumour emerge', 1),
#  ('scuffle ensued', 1),
#  ('second round', 1),
#  ('secular reformist', 1),
#  ('shall witness', 1),
#  ('shop window', 1),
#  ('short range', 1),
#  ('simultaneously published', 1),
#  ('small firebomb', 1),
#  ('sole income', 1),
#  ('something horrifying', 1),
#  ('sowing discord', 1),
#  ('starkly unequal', 1),
#  ('student coordinating', 1),
#  ('subsequent heavy', 1),
#  ('subsequently transferred', 1),
#  ('successfully repressed', 1),
#  ('suddenly accelerating', 1),
#  ('supranational organisation', 1),
#  ('swap rose', 1),
#  ('take decision', 1),
#  ('terrorist act', 1),
#  ('thorough democratization', 1),
#  ('threw stone', 1),
#  ('thus restoring', 1),
#  ('tipping point', 1),
#  ('traditionally subsidized', 1),
#  ('una rivoluzione', 1),
#  ('uncertainty blowing', 1),
#  ('witness unprecedented', 1),
#  ('ثورة الكرامة', 1),
#  ('al jazeera', 1),
#  ('saudi arabia', 1),
#  ('united states', 1),
#  ('caid essebsi', 1),
#  ('elyes jouini', 1),
#  ('reporters without', 1),
#  ('without borders', 1),
#  ('collected news', 1),
#  ('ennahda movement', 1),
#  ('civil war', 1),
#  ('.\'" finally', 1),
#  ('2015 nobel', 1),
#  ('american journalist', 1),
#  ('ammar pledged', 1),
#  ('an agreement', 1),
#  ('april prison', 1),
#  ('assembly charged', 1),
#  ('beji caid', 1),
#  ('casbah media', 1),
#  ('change collected', 1),
#  ('cooperation council', 1),
#  ('corruption portal', 1),
#  ('corruption profile', 1),
#  ('criminal court', 1),
#  ('dailymotion became', 1),
#  ('days before', 1),
#  ('economic reform', 1),
#  ('either way', 1),
#  ('employment fund', 1),
#  ('european pressphoto', 1),
#  ('ftdl quit', 1),
#  ('faida hamdi', 1),
#  ('first step', 1),
#  ('former interior', 1),
#  ('gdańsk ?".', 1),
#  ('hamdi say', 1),
#  ('hamma hammami', 1),
#  ('hosni mubarak', 1),
#  ('human rights', 1),
#  ('islamic caliphate', 1),
#  ('kairouan resulted', 1),
#  ('kefi becomes', 1),
#  ('libyan protection', 1),
#  ('mahdia freed', 1),
#  ('many government', 1),
#  ('military personnel', 1),
#  ('momentum appeared', 1),
#  ('muammar gaddafi', 1),
#  ('ngos criticized', 1),
#  ('nineties ?', 1),
#  ('osama bin', 1),
#  ('overview 2013', 1),
#  ('police claimed', 1),
#  ('polish solidarity', 1),
#  ('political overview', 1),
#  ('rachid ammar', 1),
#  ('rashid ammar', 1),
#  ('remember how', 1),
#  ('rights league', 1),
#  ('rome statute', 1),
#  ('second optional', 1),
#  ('several hundred', 1),
#  ('several webloggers', 1),
#  ('three notable', 1),
#  ('while commentator', 1),
#  ('wikileaks document', 1),
#  ('wired described', 1),
#  ('address protester', 1),
#  ('amid continuing', 1),
#  ('announcing change', 1),
#  ('appointed secretary', 1),
#  ('attorney farhat', 1),
#  ('attracts attention', 1),
#  ('became available', 1),
#  ('became convinced', 1),
#  ('before departing', 1),
#  ('blogger slim', 1),
#  ('blogging group', 1),
#  ('broadcaster rai', 1),
#  ('broadcaster shems', 1),
#  ('caused riot', 1),
#  ('citizen expressing', 1),
#  ('color revolution', 1),
#  ('commit suicide', 1),
#  ('communication technology', 1),
#  ('crime aimed', 1),
#  ('default swap', 1),
#  ('document labeled', 1),
#  ('doing enough', 1),
#  ('dominated parliament', 1),
#  ('door wide', 1),
#  ('early 1990s', 1),
#  ('early nineties', 1),
#  ('encountered each', 1),
#  ('expressed concern', 1),
#  ('expressed strong', 1),
#  ('famously captured', 1),
#  ('female officer', 1),
#  ('financial analyst', 1),
#  ('financial difficulty', 1),
#  ('funeral procession', 1),
#  ('generally considered', 1),
#  ('get ahead', 1),
#  ('giving rise', 1),
#  ('group nawaat', 1),
#  ('halt update', 1),
#  ('having formed', 1),
#  ('higher alert', 1),
#  ('holding centre', 1),
#  ('holding transparent', 1),
#  ('inciting voluntary', 1),
#  ('initially spread', 1),
#  ('intellectual themselves', 1),
#  ('internal affair', 1),
#  ('intervened heavily', 1),
#  ('journalist andy', 1),
#  ('journalist zied', 1),
#  ('large portion', 1),
#  ('leadership should', 1),
#  ('leaked document', 1),
#  ('le sympathetic', 1),
#  ('logistical help', 1),
#  ('main architect', 1),
#  ('main train', 1),
#  ('man attempting', 1),
#  ('marcher caused', 1),
#  ('marginalised issue', 1),
#  ('market index', 1),
#  ('militant group', 1),
#  ('modern conflict', 1),
#  ('notable movement', 1),
#  ('notable silence', 1),
#  ('obvious successor', 1),
#  ('official claim', 1),
#  ('opened holding', 1),
#  ('organisation expressed', 1),
#  ('organ loyal', 1),
#  ('outrage quickly', 1),
#  ('parliamentary speaker', 1),
#  ('partly answered', 1),
#  ('photojournalist working', 1),
#  ('policewoman insulted', 1),
#  ('previously successfully', 1),
#  ('private radio', 1),
#  ('private sector', 1),
#  ('prominent blogger', 1),
#  ('prominent critic', 1),
#  ('protestors marching', 1),
#  ('providing le', 1),
#  ('quickly grew', 1),
#  ('radio broadcaster', 1),
#  ('ransacking building', 1),
#  ('rapper hamada', 1),
#  ('rarely made', 1),
#  ('recently completed', 1),
#  ('relatively little', 1),
#  ('religious slogan', 1),
#  ('retained just', 1),
#  ('riot gear', 1),
#  ('roughly 20', 1),
#  ('savagely beaten', 1),
#  ('serious crime', 1),
#  ('serious trouble', 1),
#  ('sought refuge', 1),
#  ('southern area', 1),
#  ('southern fishing', 1),
#  ('sovereign default', 1),
#  ('spillover effect', 1),
#  ('staying ?', 1),
#  ('step down', 1),
#  ('stock market', 1),
#  ('telecommunication played', 1),
#  ('tell mubarak', 1),
#  ('total vote', 1),
#  ('trade union', 1),
#  ('train station', 1),
#  ('ultimately resulting', 1),
#  ('ultimately successful', 1),
#  ('unconfirmed report', 1),
#  ('unequal distribution', 1),
#  ('unjustified attack', 1),
#  ('user password', 1),
#  ('various incarnation', 1),
#  ('various message', 1),
#  ('voluntary homicide', 1),
#  ('voluntary manslaughter', 1),
#  ('warrant issued', 1),
#  ('whose song', 1),
#  ('wide open', 1),
#  ('working class', 1),
#  ('york alleged', 1),
#  ('my responsibility', 1),
#  ('fouad mebazaa', 1),
#  ('najib chebbi', 1),
#  ('arab world', 1),
#  ('more than', 1),
#  ('jazeera english', 1),
#  ('progressive democratic', 1),
#  ('prime minister', 1),
#  ('10 million', 1),
#  ('abrams noted', 1),
#  ('africa operation', 1),
#  ('all persons', 1),
#  ('ardoni carried', 1),
#  ('caïd essebsi', 1),
#  ('despite criticism', 1),
#  ('egypt where', 1),
#  ('levine argued', 1),
#  ('mark levine', 1),
#  ('modern maghreb', 1),
#  ('najib tlijali', 1),
#  ('nejib chebbi', 1),
#  ('north africa', 1),
#  ('northern africa', 1),
#  ('nouri jouini', 1),
#  ('protesters threw', 1),
#  ('soldiers retired', 1),
#  ('these included', 1),
#  ('thousands participate', 1),
#  ('without alerting', 1),
#  ('anonymity network', 1),
#  ('apple cart', 1),
#  ('attacked shop', 1),
#  ('began speculation', 1),
#  ('burning tire', 1),
#  ('causing casualty', 1),
#  ('chief khaled', 1),
#  ('chief rachid', 1),
#  ('confiscating produce', 1),
#  ('coordinating food', 1),
#  ('curb immigration', 1),
#  ('current refugee', 1),
#  ('damaged car', 1),
#  ('death penalty', 1),
#  ('death attributed', 1),
#  ('democratic opening', 1),
#  ('departing office', 1),
#  ('disbands itself', 1),
#  ('dispersing youth', 1),
#  ('economist living', 1),
#  ('ed article', 1),
#  ('ending 23', 1),
#  ('extensively deployed', 1),
#  ('external group', 1),
#  ('fatally shot', 1)]

# %% [markdown]
# Languages: en, fr, ar
# Keywords:
# - Tunisia: tunis+
# - Egypt: egypt

# %% [markdown]
# # Helper Functions

# %% [markdown]
# # Main

# %% [markdown]
# # Reading a Single `.protostream` File

# %% [markdown]
# # Selecting filtering Keywords

# %% [markdown]
# Let's analyse the [Wikipedia page](https://en.wikipedia.org/wiki/Tunisian_Revolution) for the thematic we are interested in:
